# %% [markdown]
# ### Create your data lake using S3 ##

# %%
# Once you managed to build your dataset, you should store into S3 as a csv file.

# !pip install Boto3
# Out:
# Requirement already satisfied: Boto3 in /opt/conda/lib/python3.9/site-packages (1.23.1)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /opt/conda/lib/python3.9/site-packages (from Boto3) (0.5.2)
# Requirement already satisfied: botocore<1.27.0,>=1.26.1 in /opt/conda/lib/python3.9/site-packages (from Boto3) (1.26.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.9/site-packages (from Boto3) (1.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.9/site-packages (from botocore<1.27.0,>=1.26.1->Boto3) (1.26.8)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.9/site-packages (from botocore<1.27.0,>=1.26.1->Boto3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.27.0,>=1.26.1->Boto3) (1.16.0)

# %%
import boto3

session = boto3.Session(aws_access_key_id="AKIAYTU4VQSYBA3THKZ7", 
                        aws_secret_access_key="xxxxxxxxxxxxx")

# %%
s3 = session.resource("s3")

# %%
bucket = s3.create_bucket(Bucket="kayak-project22")

# %%
import pandas as pd

# %%
Booking35 = pd.read_csv("booking35.csv")
Booking35
# Out:
#     index                   destination        lat       lon          dt  \
# 0       1             Mont Saint Michel  48.635954 -1.511460  1650620833
# 1       2                       St Malo  48.649518 -2.026041  1650620833
# 2       3                        Bayeux  49.276462 -0.702474  1650620833
# 3       4                      Le Havre  49.493898  0.107973  1650620834
# 4       5                         Rouen  49.440459  1.093966  1650620834
# 5       6                         Paris  48.858890  2.320041  1650620834
# 6       7                        Amiens  49.894171  2.295695  1650620834
# 7       8                         Lille  50.636565  3.063528  1650620834
# 8       9                    Strasbourg  48.584614  7.750713  1650620834
# 9      10  Chateau du Haut Koenigsbourg  48.249490  7.344296  1650620834
# 10     11                        Colmar  48.077752  7.357964  1650620835
# 11     12                     Eguisheim  48.044797  7.307962  1650620835
# 12     13                      Besancon  47.238022  6.024362  1650620835
# 13     14                         Dijon  47.321581  5.041470  1650620835
# 14     15                        Annecy  45.899235  6.128885  1650620835
# 15     16                      Grenoble  45.187560  5.735782  1650620835
# 16     17                          Lyon  45.757814  4.832011  1650620835
# 17     18              Gorges du Verdon  43.749656  6.328562  1650620835
# 18     19            Bormes les Mimosas  43.157217  6.329254  1650620835
# 19     20                        Cassis  43.214036  5.539632  1650620835
# 20     21                     Marseille  43.296174  5.369953  1650620835
# 21     22               Aix en Provence  43.529842  5.447474  1650620836
# 22     23                       Avignon  43.949249  4.805901  1650620836
# 23     24                          Uzes  44.012128  4.419672  1650620836
# 24     25                         Nimes  43.837425  4.360069  1650620836
# 25     26                 Aigues Mortes  43.565823  4.191284  1650620836
# 26     27      Saintes Maries de la mer  43.452277  4.428717  1650620836
# 27     28                     Collioure  42.525050  3.083155  1650620836
# 28     29                   Carcassonne  43.213036  2.349107  1650620836
# 29     30                        Ariege  42.945537  1.406554  1650620836
# 30     31                      Toulouse  43.604462  1.444247  1650620836
# 31     32                     Montauban  44.017584  1.354999  1650620837
# 32     33                      Biarritz  43.483252 -1.559278  1650620837
# 33     34                       Bayonne  43.493338 -1.475099  1650620837
# 34     35                   La Rochelle  46.159113 -1.152043  1650620837
#
#       temp  pressure      description                                 Link  \
# 0   287.54      1002  overcast clouds  https://www.booking.com#basiclayout
# 1   287.86      1002  overcast clouds  https://www.booking.com#basiclayout
# 2   286.29      1003    broken clouds  https://www.booking.com#basiclayout
# 3   288.66      1003        clear sky  https://www.booking.com#basiclayout
# 4   288.12      1002        clear sky  https://www.booking.com#basiclayout
# 5   289.17      1002       few clouds  https://www.booking.com#basiclayout
# 6   288.77      1004       few clouds  https://www.booking.com#basiclayout
# 7   288.19      1004       few clouds  https://www.booking.com#basiclayout
# 8   287.87      1002        clear sky  https://www.booking.com#basiclayout
# 9   283.27      1001        clear sky  https://www.booking.com#basiclayout
# 10  286.71      1001        clear sky  https://www.booking.com#basiclayout
# 11  286.54      1001        clear sky  https://www.booking.com#basiclayout
# 12  289.52       999    broken clouds  https://www.booking.com#basiclayout
# 13  287.95      1000        clear sky  https://www.booking.com#basiclayout
# 14  287.14      1000        clear sky  https://www.booking.com#basiclayout
# 15  289.25       999  overcast clouds  https://www.booking.com#basiclayout
# 16  288.88      1000        clear sky  https://www.booking.com#basiclayout
# 17  285.43      1000  overcast clouds  https://www.booking.com#basiclayout
# 18  288.80      1000    broken clouds  https://www.booking.com#basiclayout
# 19  289.52      1001    broken clouds  https://www.booking.com#basiclayout
# 20  289.43       999    broken clouds  https://www.booking.com#basiclayout
# 21  289.50       999    broken clouds  https://www.booking.com#basiclayout
# 22  289.32       999       few clouds  https://www.booking.com#basiclayout
# 23  290.47       999    broken clouds  https://www.booking.com#basiclayout
# 24  292.15      1000        clear sky  https://www.booking.com#basiclayout
# 25  290.13      1000        clear sky  https://www.booking.com#basiclayout
# 26  292.69      1000    broken clouds  https://www.booking.com#basiclayout
# 27  292.18      1000    broken clouds  https://www.booking.com#basiclayout
# 28  287.92      1000    broken clouds  https://www.booking.com#basiclayout
# 29  283.46      1000  overcast clouds  https://www.booking.com#basiclayout
# 30  288.22      1001  overcast clouds  https://www.booking.com#basiclayout
# 31  286.21      1000  overcast clouds  https://www.booking.com#basiclayout
# 32  289.16       998        clear sky  https://www.booking.com#basiclayout
# 33  289.18       998        clear sky  https://www.booking.com#basiclayout
# 34  287.22       999  overcast clouds  https://www.booking.com#basiclayout
#
#                                                 House  \
# 0                                          Hôtel Vert
# 1                     Hôtel Bristol Union Intra Muros
# 2                                   Domaine de Bayeux
# 3               Holiday Inn Express - Le Havre Centre
# 4                    Radisson Blu Hotel, Rouen Centre
# 5                                      L'Empire Paris
# 6            Holiday Inn Express Amiens, an IHG Hotel
# 7                            NOCNOC - La Villa Cachee
# 8                  Ibis Budget Strasbourg Centre Gare
# 9                   Les Chambres du Haut-Koenigsbourg
# 10  Le Parc - Standing apartments in front of the ...
# 11                   James Vignoble Hôtel - Eguisheim
# 12                               Hôtel AKENA BESANCON
# 13                                    ibis Dijon Gare
# 14               Le Luxury Design de la Vieille Ville
# 15               Esprit Bistrot / Rent4night Grenoble
# 16        Residence Montempo Lyon Cite Internationale
# 17     La Bastide du Calalou; BW Signature Collection
# 18                                   Le petit atelier
# 19  UNE TERRASSE SUR LA MER 4 pers 2 chambres VUE MER
# 20             Meininger Marseille Centre la Joliette
# 21             TheCamp Hotel&Lodges - Aix en Provence
# 22                  Kyriad Avignon - Palais des Papes
# 23    Nice apartment in Uzès with WiFi and 1 Bedrooms
# 24                                        Royal Hôtel
# 25                CABANE DU SAUNIER MAIA ETANG DU ROY
# 26                                    Mas De Calabrun
# 27                             Le Mas des Citronniers
# 28                                 Domaine Le Couvent
# 29                                   dtente sky lodge
# 30                                L'Ecuyer by Cocoonr
# 31                       Brit Hotel Confort Montauban
# 32                                    Studio Biarritz
# 33                               Villa la Renaissance
# 34                            Appart'City La Rochelle
#
#                                           Description Score
# 0   Situé à 2 km du Mont-Saint-Michel, sur la côte...   8,1
# 1   L’Hôtel Bristol Union Intra Muros est situé au...   8,6
# 2   Le Domaine de Bayeux occupe une maison du XVII...   9,4
# 3   L’Holiday Inn Express - Le Havre Centre, situé...   8,2
# 4   Situé à Rouen, le Radisson Blu Hotel, Rouen Ce...   8,9
# 5                        Établissement Voyage Durable   8,2
# 6   Rénové en avril 2015, le Holiday Inn Express A...   8,1
# 7   Doté d'une connexion Wi-Fi et d'un parking pri...   8,4
# 8   Situé à Strasbourg, l’ibis Budget Strasbourg C...   7,9
# 9   Situé à Orschwiller, en Alsace, l'établissemen...   8,8
# 10  Offrant une vue sur la ville et doté d'une con...   9,2
# 11  Le James Vignoble Hôtel - Eguisheim vous accue...   8,8
# 12  Situé à Besançon, à 7 km du parc Micropolis, l...   8,7
# 13                       Établissement Voyage Durable   8,0
# 14  Situé à Annecy, à 100 mètres du château et à 2...   9,3
# 15                Hébergement géré par un particulier   8,2
# 16  La Residence Montempo Lyon Cite Internationale...   7,8
# 17                       Établissement Voyage Durable   8,4
# 18                Hébergement géré par un particulier   9,0
# 19  Situé à Cassis, à seulement 100 mètres de Best...   8,7
# 20  Doté d'un bar, d'un salon commun et offrant un...   8,7
# 21                       Établissement Voyage Durable   8,6
# 22  Le Kyriad Avignon - Palais des Papes vous accu...   8,1
# 23  Le Nice apartment in Uzès with WiFi and 1 Bedr...   8,9
# 24  Situé au cœur de Nîmes, le Royal Hôtel dispose...   8,2
# 25                Hébergement géré par un particulier   9,1
# 26  Doté d’une piscine extérieure, d’un terrain de...   8,6
# 27  Situé dans le centre de Collioure, à seulement...   8,0
# 28                       Établissement Voyage Durable   9,3
# 29                Hébergement géré par un particulier   9,4
# 30  Situé dans le centre de Toulouse, à seulement ...   8,4
# 31  Le Brit Hotel Confort Montauban est situé au s...   7,5
# 32                Hébergement géré par un particulier   8,4
# 33  La Villa la Renaissance propose des chambres à...   9,2
# 34                       Établissement Voyage Durable   7,3

# %%
csv = Booking35.to_csv()

# %%
put_object = bucket.put_object(Key="booking35.csv", Body=csv)

# %% [markdown]
# ### Create a SQL Database using AWS RDS ###

# %%
# Once you uploaded your data onto S3, it will be better for the next data analysis team
# to extract clean data directly from a Data Warehouse. Therefore, create a SQL Database using AWS RDS, 
# extract your data from S3 and store it in your newly created DB.

# %%
# !pip install psycopg2-binary # For PostgreSQL
# !pip install pymysql
# Out:
# Requirement already satisfied: psycopg2-binary in /opt/conda/lib/python3.9/site-packages (2.9.3)
# Requirement already satisfied: pymysql in /opt/conda/lib/python3.9/site-packages (1.0.2)

# %%
DBHOST = "kayak-database.cgdvtyzjq0cu.eu-west-3.rds.amazonaws.com"
DBUSER = "gregatcole"
DBPASS = "xxxxxxxxx"
DBNAME = "UserGreg"

# %% [markdown]
# ### Store S3 datas to DB SQL ###

# %%
from sqlalchemy import create_engine, text

# Replace HOSTNAME by AWS RDS Endpoint, USERNAME and PASSWORD by its credentials

engine = create_engine(f"postgresql+psycopg2://{DBUSER}:{DBPASS}@{DBHOST}/{DBNAME}", echo=True)
engine
# Out:
# Engine(postgresql+psycopg2://gregatcole:***@kayak-database.cgdvtyzjq0cu.eu-west-3.rds.amazonaws.com/UserGreg)

# %%
# Push the booking35 dataframe to my sql database

Booking35.to_sql("Booking35",engine)
# Out:
# 2022-05-17 11:48:06,924 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2022-05-17 11:48:06,925 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-17 11:48:06,937 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-05-17 11:48:06,938 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-17 11:48:06,950 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-05-17 11:48:06,951 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-05-17 11:48:06,964 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-05-17 11:48:06,965 INFO sqlalchemy.engine.Engine [generated in 0.00129s] {'name': 'Booking35'}
# 2022-05-17 11:48:06,985 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-05-17 11:48:06,988 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Booking35" (
# 	level_0 BIGINT,
# 	index BIGINT,
# 	destination TEXT,
# 	lat FLOAT(53),
# 	lon FLOAT(53),
# 	dt BIGINT,
# 	temp FLOAT(53),
# 	pressure BIGINT,
# 	description TEXT,
# 	"Link" TEXT,
# 	"House" TEXT,
# 	"Description" TEXT,
# 	"Score" TEXT
# )
#
#
# 2022-05-17 11:48:06,989 INFO sqlalchemy.engine.Engine [no key 0.00117s] {}
# 2022-05-17 11:48:07,011 INFO sqlalchemy.engine.Engine CREATE INDEX "ix_Booking35_level_0" ON "Booking35" (level_0)
# 2022-05-17 11:48:07,012 INFO sqlalchemy.engine.Engine [no key 0.00109s] {}
# 2022-05-17 11:48:07,023 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-17 11:48:07,033 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-05-17 11:48:07,037 INFO sqlalchemy.engine.Engine INSERT INTO "Booking35" (level_0, index, destination, lat, lon, dt, temp, pressure, description, "Link", "House", "Description", "Score") VALUES (%(level_0)s, %(index)s, %(destination)s, %(lat)s, %(lon)s, %(dt)s, %(temp)s, %(pressure)s, %(description)s, %(Link)s, %(House)s, %(Description)s, %(Score)s)
# 2022-05-17 11:48:07,038 INFO sqlalchemy.engine.Engine [generated in 0.00171s] ({'level_0': 0, 'index': 1, 'destination': 'Mont Saint Michel', 'lat': 48.6359541, 'lon': -1.5114599549595142, 'dt': 1650620833, 'temp': 287.54, 'pressure': 1002, 'description': 'overcast clouds', 'Link': 'https://www.booking.com#basiclayout', 'House': 'Hôtel Vert', 'Description': "Situé à 2 km du Mont-Saint-Michel, sur la côte normande, l'Hôtel Vert propose des chambres décorées dans des tons pastel dotées d'une salle de bains privative, d'une télévision ainsi que d'une...", 'Score': '8,1'}, {'level_0': 1, 'index': 2, 'destination': 'St Malo', 'lat': 48.649518, 'lon': -2.0260409, 'dt': 1650620833, 'temp': 287.86, 'pressure': 1002, 'description': 'overcast clouds', 'Link': 'https://www.booking.com#basiclayout', 'House': 'Hôtel Bristol Union Intra Muros', 'Description': 'L’Hôtel Bristol Union Intra Muros est situé au cœur de Saint-Malo, dans l’enceinte des remparts de la vieille ville, à 180\xa0mètres du port de plaisance. ', 'Score': '8,6'}, {'level_0': 2, 'index': 3, 'destination': 'Bayeux', 'lat': 49.2764624, 'lon': -0.7024738, 'dt': 1650620833, 'temp': 286.29, 'pressure': 1003, 'description': 'broken clouds', 'Link': 'https://www.booking.com#basiclayout', 'House': 'Domaine de Bayeux', 'Description': 'Le Domaine de Bayeux occupe une maison du XVIIIe siècle avec un parc arboré dans le centre de Bayeux. ', 'Score': '9,4'}, {'level_0': 3, 'index': 4, 'destination': 'Le Havre', 'lat': 49.4938975, 'lon': 0.1079731999999999, 'dt': 1650620834, 'temp': 288.66, 'pressure': 1003, 'description': 'clear sky', 'Link': 'https://www.booking.com#basiclayout', 'House': 'Holiday Inn Express - Le Havre Centre', 'Description': 'L’Holiday Inn Express - Le Havre Centre, situé dans le centre-ville du Havre et à 600\xa0mètres de la gare SNCF, vous accueille pour un séjour professionnel et de loisirs. ', 'Score': '8,2'}, {'level_0': 4, 'index': 5, 'destination': 'Rouen', 'lat': 49.4404591, 'lon': 1.0939658, 'dt': 1650620834, 'temp': 288.12, 'pressure': 1002, 'description': 'clear sky', 'Link': 'https://www.booking.com#basiclayout', 'House': 'Radisson Blu Hotel, Rouen Centre', 'Description': "Situé à Rouen, le Radisson Blu Hotel, Rouen Centre dispose d'un restaurant servant des plats locaux de haute qualité, d'une salle de sport, d'un bar et d'un salon commun. ", 'Score': '8,9'}, {'level_0': 5, 'index': 6, 'destination': 'Paris', 'lat': 48.858889700000006, 'lon': 2.3200410217200766, 'dt': 1650620834, 'temp': 289.17, 'pressure': 1002, 'description': 'few clouds', 'Link': 'https://www.booking.com#basiclayout', 'House': "L'Empire Paris", 'Description': 'Établissement Voyage Durable', 'Score': '8,2'}, {'level_0': 6, 'index': 7, 'destination': 'Amiens', 'lat': 49.8941708, 'lon': 2.2956951, 'dt': 1650620834, 'temp': 288.77, 'pressure': 1004, 'description': 'few clouds', 'Link': 'https://www.booking.com#basiclayout', 'House': 'Holiday Inn Express Amiens, an IHG Hotel', 'Description': 'Rénové en avril\xa02015, le Holiday Inn Express Amiens comprend des chambres confortables avec une connexion Wi-Fi gratuite. ', 'Score': '8,1'}, {'level_0': 7, 'index': 8, 'destination': 'Lille', 'lat': 50.6365654, 'lon': 3.0635282000000004, 'dt': 1650620834, 'temp': 288.19, 'pressure': 1004, 'description': 'few clouds', 'Link': 'https://www.booking.com#basiclayout', 'House': 'NOCNOC - La Villa Cachee', 'Description': "Doté d'une connexion Wi-Fi et d'un parking privé gratuits, le NOCNOC - La Villa Cachee est situé à Lille, à seulement 400 mètres de la maison Coilliot. ", 'Score': '8,4'}  ... displaying 10 of 35 total bound parameter sets ...  {'level_0': 33, 'index': 34, 'destination': 'Bayonne', 'lat': 43.49333789999999, 'lon': -1.475099, 'dt': 1650620837, 'temp': 289.18, 'pressure': 998, 'description': 'clear sky', 'Link': 'https://www.booking.com#basiclayout', 'House': 'Villa la Renaissance', 'Description': "La Villa la Renaissance propose des chambres à Bayonne, à 600 mètres du parc Ansot et à 1, ...
# 2022-05-17 11:48:07,055 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-17 11:48:07,064 INFO sqlalchemy.engine.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2022-05-17 11:48:07,065 INFO sqlalchemy.engine.Engine [generated in 0.00097s] {'schema': 'public'}
# 35

# %%
import pandas as pd
pd.read_sql_table('Booking35', engine, index_col='index')
# Out:
# 2022-05-17 11:48:11,423 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-05-17 11:48:11,425 INFO sqlalchemy.engine.Engine [cached since 4.461s ago] {'name': 'Booking35'}
# 2022-05-17 11:48:11,444 INFO sqlalchemy.engine.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2022-05-17 11:48:11,445 INFO sqlalchemy.engine.Engine [generated in 0.00141s] {'table_name': 'Booking35'}
# 2022-05-17 11:48:11,458 INFO sqlalchemy.engine.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (
#                 SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                 WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                 AND a.atthasdef
#               ) AS DEFAULT,
#               a.attnotnull,
#               a.attrelid as table_oid,
#               pgd.description as comment,
#               a.attgenerated as generated,
#                               (SELECT json_build_object(
#                     'always', a.attidentity = 'a',
#                     'start', s.seqstart,
#                     'increment', s.seqincrement,
#                     'minvalue', s.seqmin,
#                     'maxvalue', s.seqmax,
#                     'cache', s.seqcache,
#                     'cycle', s.seqcycle)
#                 FROM pg_catalog.pg_sequence s
#                 JOIN pg_catalog.pg_class c on s.seqrelid = c."oid"
#                 WHERE c.relkind = 'S'
#                 AND a.attidentity != ''
#                 AND s.seqrelid = pg_catalog.pg_get_serial_sequence(
#                     a.attrelid::regclass::text, a.attname
#                 )::regclass::oid
#                 ) as identity_options
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2022-05-17 11:48:11,459 INFO sqlalchemy.engine.Engine [generated in 0.00113s] {'table_oid': 16414}
# 2022-05-17 11:48:11,468 INFO sqlalchemy.engine.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2022-05-17 11:48:11,469 INFO sqlalchemy.engine.Engine [generated in 0.00098s] {}
# 2022-05-17 11:48:11,477 INFO sqlalchemy.engine.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2022-05-17 11:48:11,478 INFO sqlalchemy.engine.Engine [generated in 0.00096s] {}
# 2022-05-17 11:48:11,490 INFO sqlalchemy.engine.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2022-05-17 11:48:11,492 INFO sqlalchemy.engine.Engine [generated in 0.00115s] {'table_oid': 16414}
# 2022-05-17 11:48:11,499 INFO sqlalchemy.engine.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2022-05-17 11:48:11,500 INFO sqlalchemy.engine.Engine [generated in 0.00103s] {'table_oid': 16414}
# 2022-05-17 11:48:11,508 INFO sqlalchemy.engine.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2022-05-17 11:48:11,509 INFO sqlalchemy.engine.Engine [generated in 0.00103s] {'table': 16414}
# 2022-05-17 11:48:11,516 INFO sqlalchemy.engine.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   pg_get_expr(ix.indpred, ix.indrelid),
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2022-05-17 11:48:11,517 INFO sqlalchemy.engine.Engine [generated in 0.00132s] {'table_oid': 16414}
# 2022-05-17 11:48:11,526 INFO sqlalchemy.engine.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2022-05-17 11:48:11,527 INFO sqlalchemy.engine.Engine [generated in 0.00115s] {'table_oid': 16414}
# 2022-05-17 11:48:11,535 INFO sqlalchemy.engine.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2022-05-17 11:48:11,536 INFO sqlalchemy.engine.Engine [generated in 0.00125s] {'table_oid': 16414}
# 2022-05-17 11:48:11,543 INFO sqlalchemy.engine.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2022-05-17 11:48:11,544 INFO sqlalchemy.engine.Engine [generated in 0.00097s] {'table_oid': 16414}
# 2022-05-17 11:48:11,558 INFO sqlalchemy.engine.Engine SELECT "Booking35".level_0, "Booking35".index, "Booking35".destination, "Booking35".lat, "Booking35".lon, "Booking35".dt, "Booking35".temp, "Booking35".pressure, "Booking35".description, "Booking35"."Link", "Booking35"."House", "Booking35"."Description", "Booking35"."Score"
# FROM "Booking35"
# 2022-05-17 11:48:11,559 INFO sqlalchemy.engine.Engine [generated in 0.00105s] {}
#        level_0                   destination        lat       lon          dt  \
# index
# 1            0             Mont Saint Michel  48.635954 -1.511460  1650620833
# 2            1                       St Malo  48.649518 -2.026041  1650620833
# 3            2                        Bayeux  49.276462 -0.702474  1650620833
# 4            3                      Le Havre  49.493898  0.107973  1650620834
# 5            4                         Rouen  49.440459  1.093966  1650620834
# 6            5                         Paris  48.858890  2.320041  1650620834
# 7            6                        Amiens  49.894171  2.295695  1650620834
# 8            7                         Lille  50.636565  3.063528  1650620834
# 9            8                    Strasbourg  48.584614  7.750713  1650620834
# 10           9  Chateau du Haut Koenigsbourg  48.249490  7.344296  1650620834
# 11          10                        Colmar  48.077752  7.357964  1650620835
# 12          11                     Eguisheim  48.044797  7.307962  1650620835
# 13          12                      Besancon  47.238022  6.024362  1650620835
# 14          13                         Dijon  47.321581  5.041470  1650620835
# 15          14                        Annecy  45.899235  6.128885  1650620835
# 16          15                      Grenoble  45.187560  5.735782  1650620835
# 17          16                          Lyon  45.757814  4.832011  1650620835
# 18          17              Gorges du Verdon  43.749656  6.328562  1650620835
# 19          18            Bormes les Mimosas  43.157217  6.329254  1650620835
# 20          19                        Cassis  43.214036  5.539632  1650620835
# 21          20                     Marseille  43.296174  5.369953  1650620835
# 22          21               Aix en Provence  43.529842  5.447474  1650620836
# 23          22                       Avignon  43.949249  4.805901  1650620836
# 24          23                          Uzes  44.012128  4.419672  1650620836
# 25          24                         Nimes  43.837425  4.360069  1650620836
# 26          25                 Aigues Mortes  43.565823  4.191284  1650620836
# 27          26      Saintes Maries de la mer  43.452277  4.428717  1650620836
# 28          27                     Collioure  42.525050  3.083155  1650620836
# 29          28                   Carcassonne  43.213036  2.349107  1650620836
# 30          29                        Ariege  42.945537  1.406554  1650620836
# 31          30                      Toulouse  43.604462  1.444247  1650620836
# 32          31                     Montauban  44.017584  1.354999  1650620837
# 33          32                      Biarritz  43.483252 -1.559278  1650620837
# 34          33                       Bayonne  43.493338 -1.475099  1650620837
# 35          34                   La Rochelle  46.159113 -1.152043  1650620837
#
#          temp  pressure      description                                 Link  \
# index
# 1      287.54      1002  overcast clouds  https://www.booking.com#basiclayout
# 2      287.86      1002  overcast clouds  https://www.booking.com#basiclayout
# 3      286.29      1003    broken clouds  https://www.booking.com#basiclayout
# 4      288.66      1003        clear sky  https://www.booking.com#basiclayout
# 5      288.12      1002        clear sky  https://www.booking.com#basiclayout
# 6      289.17      1002       few clouds  https://www.booking.com#basiclayout
# 7      288.77      1004       few clouds  https://www.booking.com#basiclayout
# 8      288.19      1004       few clouds  https://www.booking.com#basiclayout
# 9      287.87      1002        clear sky  https://www.booking.com#basiclayout
# 10     283.27      1001        clear sky  https://www.booking.com#basiclayout
# 11     286.71      1001        clear sky  https://www.booking.com#basiclayout
# 12     286.54      1001        clear sky  https://www.booking.com#basiclayout
# 13     289.52       999    broken clouds  https://www.booking.com#basiclayout
# 14     287.95      1000        clear sky  https://www.booking.com#basiclayout
# 15     287.14      1000        clear sky  https://www.booking.com#basiclayout
# 16     289.25       999  overcast clouds  https://www.booking.com#basiclayout
# 17     288.88      1000        clear sky  https://www.booking.com#basiclayout
# 18     285.43      1000  overcast clouds  https://www.booking.com#basiclayout
# 19     288.80      1000    broken clouds  https://www.booking.com#basiclayout
# 20     289.52      1001    broken clouds  https://www.booking.com#basiclayout
# 21     289.43       999    broken clouds  https://www.booking.com#basiclayout
# 22     289.50       999    broken clouds  https://www.booking.com#basiclayout
# 23     289.32       999       few clouds  https://www.booking.com#basiclayout
# 24     290.47       999    broken clouds  https://www.booking.com#basiclayout
# 25     292.15      1000        clear sky  https://www.booking.com#basiclayout
# 26     290.13      1000        clear sky  https://www.booking.com#basiclayout
# 27     292.69      1000    broken clouds  https://www.booking.com#basiclayout
# 28     292.18      1000    broken clouds  https://www.booking.com#basiclayout
# 29     287.92      1000    broken clouds  https://www.booking.com#basiclayout
# 30     283.46      1000  overcast clouds  https://www.booking.com#basiclayout
# 31     288.22      1001  overcast clouds  https://www.booking.com#basiclayout
# 32     286.21      1000  overcast clouds  https://www.booking.com#basiclayout
# 33     289.16       998        clear sky  https://www.booking.com#basiclayout
# 34     289.18       998        clear sky  https://www.booking.com#basiclayout
# 35     287.22       999  overcast clouds  https://www.booking.com#basiclayout
#
#                                                    House  \
# index
# 1                                             Hôtel Vert
# 2                        Hôtel Bristol Union Intra Muros
# 3                                      Domaine de Bayeux
# 4                  Holiday Inn Express - Le Havre Centre
# 5                       Radisson Blu Hotel, Rouen Centre
# 6                                         L'Empire Paris
# 7               Holiday Inn Express Amiens, an IHG Hotel
# 8                               NOCNOC - La Villa Cachee
# 9                     Ibis Budget Strasbourg Centre Gare
# 10                     Les Chambres du Haut-Koenigsbourg
# 11     Le Parc - Standing apartments in front of the ...
# 12                      James Vignoble Hôtel - Eguisheim
# 13                                  Hôtel AKENA BESANCON
# 14                                       ibis Dijon Gare
# 15                  Le Luxury Design de la Vieille Ville
# 16                  Esprit Bistrot / Rent4night Grenoble
# 17           Residence Montempo Lyon Cite Internationale
# 18        La Bastide du Calalou; BW Signature Collection
# 19                                      Le petit atelier
# 20     UNE TERRASSE SUR LA MER 4 pers 2 chambres VUE MER
# 21                Meininger Marseille Centre la Joliette
# 22                TheCamp Hotel&Lodges - Aix en Provence
# 23                     Kyriad Avignon - Palais des Papes
# 24       Nice apartment in Uzès with WiFi and 1 Bedrooms
# 25                                           Royal Hôtel
# 26                   CABANE DU SAUNIER MAIA ETANG DU ROY
# 27                                       Mas De Calabrun
# 28                                Le Mas des Citronniers
# 29                                    Domaine Le Couvent
# 30                                      dtente sky lodge
# 31                                   L'Ecuyer by Cocoonr
# 32                          Brit Hotel Confort Montauban
# 33                                       Studio Biarritz
# 34                                  Villa la Renaissance
# 35                               Appart'City La Rochelle
#
#                                              Description Score
# index
# 1      Situé à 2 km du Mont-Saint-Michel, sur la côte...   8,1
# 2      L’Hôtel Bristol Union Intra Muros est situé au...   8,6
# 3      Le Domaine de Bayeux occupe une maison du XVII...   9,4
# 4      L’Holiday Inn Express - Le Havre Centre, situé...   8,2
# 5      Situé à Rouen, le Radisson Blu Hotel, Rouen Ce...   8,9
# 6                           Établissement Voyage Durable   8,2
# 7      Rénové en avril 2015, le Holiday Inn Express A...   8,1
# 8      Doté d'une connexion Wi-Fi et d'un parking pri...   8,4
# 9      Situé à Strasbourg, l’ibis Budget Strasbourg C...   7,9
# 10     Situé à Orschwiller, en Alsace, l'établissemen...   8,8
# 11     Offrant une vue sur la ville et doté d'une con...   9,2
# 12     Le James Vignoble Hôtel - Eguisheim vous accue...   8,8
# 13     Situé à Besançon, à 7 km du parc Micropolis, l...   8,7
# 14                          Établissement Voyage Durable   8,0
# 15     Situé à Annecy, à 100 mètres du château et à 2...   9,3
# 16                   Hébergement géré par un particulier   8,2
# 17     La Residence Montempo Lyon Cite Internationale...   7,8
# 18                          Établissement Voyage Durable   8,4
# 19                   Hébergement géré par un particulier   9,0
# 20     Situé à Cassis, à seulement 100 mètres de Best...   8,7
# 21     Doté d'un bar, d'un salon commun et offrant un...   8,7
# 22                          Établissement Voyage Durable   8,6
# 23     Le Kyriad Avignon - Palais des Papes vous accu...   8,1
# 24     Le Nice apartment in Uzès with WiFi and 1 Bedr...   8,9
# 25     Situé au cœur de Nîmes, le Royal Hôtel dispose...   8,2
# 26                   Hébergement géré par un particulier   9,1
# 27     Doté d’une piscine extérieure, d’un terrain de...   8,6
# 28     Situé dans le centre de Collioure, à seulement...   8,0
# 29                          Établissement Voyage Durable   9,3
# 30                   Hébergement géré par un particulier   9,4
# 31     Situé dans le centre de Toulouse, à seulement ...   8,4
# 32     Le Brit Hotel Confort Montauban est situé au s...   7,5
# 33                   Hébergement géré par un particulier   8,4
# 34     La Villa la Renaissance propose des chambres à...   9,2
# 35                          Établissement Voyage Durable   7,3

# %% [markdown]
# ### Top-5 destinations ###

# %%
! pip install plotly
import plotly.graph_objects as go
import plotly.io as pio
import plotly.express as px
pio.renderers.default = "iframe_connected"
# Out:
# Requirement already satisfied: plotly in /opt/conda/lib/python3.9/site-packages (5.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from plotly) (1.16.0)

# %%
# set up the TOP 5 with temp
Top5 = Booking35.sort_values(by='temp', ascending=False)
Top5 = Top5.iloc[0:5,:]
Top5
# Out:
#     index               destination        lat       lon          dt    temp  \
# 26     27  Saintes Maries de la mer  43.452277  4.428717  1650620836  292.69
# 27     28                 Collioure  42.525050  3.083155  1650620836  292.18
# 24     25                     Nimes  43.837425  4.360069  1650620836  292.15
# 23     24                      Uzes  44.012128  4.419672  1650620836  290.47
# 25     26             Aigues Mortes  43.565823  4.191284  1650620836  290.13
#
#     pressure    description                                 Link  \
# 26      1000  broken clouds  https://www.booking.com#basiclayout
# 27      1000  broken clouds  https://www.booking.com#basiclayout
# 24      1000      clear sky  https://www.booking.com#basiclayout
# 23       999  broken clouds  https://www.booking.com#basiclayout
# 25      1000      clear sky  https://www.booking.com#basiclayout
#
#                                               House  \
# 26                                  Mas De Calabrun
# 27                           Le Mas des Citronniers
# 24                                      Royal Hôtel
# 23  Nice apartment in Uzès with WiFi and 1 Bedrooms
# 25              CABANE DU SAUNIER MAIA ETANG DU ROY
#
#                                           Description Score
# 26  Doté d’une piscine extérieure, d’un terrain de...   8,6
# 27  Situé dans le centre de Collioure, à seulement...   8,0
# 24  Situé au cœur de Nîmes, le Royal Hôtel dispose...   8,2
# 23  Le Nice apartment in Uzès with WiFi and 1 Bedr...   8,9
# 25                Hébergement géré par un particulier   9,1

# %%
# To Display map with TOP5 best temperatures destination

fig = px.scatter_mapbox(Top5, lat='lat', lon='lon', size = 'temp', opacity=0.4, mapbox_style="carto-positron",color = "temp", zoom=4.5)
fig.show(renderer = "iframe_connected")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_31.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Top-20 hotels in the area ###

# %%
Top20 = Booking35.sort_values(by='Score', ascending=False)
Top20 = Top20.iloc[0:20,:]
Top20
# Out:
#     index                   destination        lat       lon          dt  \
# 2       3                        Bayeux  49.276462 -0.702474  1650620833
# 29     30                        Ariege  42.945537  1.406554  1650620836
# 28     29                   Carcassonne  43.213036  2.349107  1650620836
# 14     15                        Annecy  45.899235  6.128885  1650620835
# 33     34                       Bayonne  43.493338 -1.475099  1650620837
# 10     11                        Colmar  48.077752  7.357964  1650620835
# 25     26                 Aigues Mortes  43.565823  4.191284  1650620836
# 18     19            Bormes les Mimosas  43.157217  6.329254  1650620835
# 23     24                          Uzes  44.012128  4.419672  1650620836
# 4       5                         Rouen  49.440459  1.093966  1650620834
# 11     12                     Eguisheim  48.044797  7.307962  1650620835
# 9      10  Chateau du Haut Koenigsbourg  48.249490  7.344296  1650620834
# 12     13                      Besancon  47.238022  6.024362  1650620835
# 20     21                     Marseille  43.296174  5.369953  1650620835
# 19     20                        Cassis  43.214036  5.539632  1650620835
# 26     27      Saintes Maries de la mer  43.452277  4.428717  1650620836
# 21     22               Aix en Provence  43.529842  5.447474  1650620836
# 1       2                       St Malo  48.649518 -2.026041  1650620833
# 17     18              Gorges du Verdon  43.749656  6.328562  1650620835
# 32     33                      Biarritz  43.483252 -1.559278  1650620837
#
#       temp  pressure      description                                 Link  \
# 2   286.29      1003    broken clouds  https://www.booking.com#basiclayout
# 29  283.46      1000  overcast clouds  https://www.booking.com#basiclayout
# 28  287.92      1000    broken clouds  https://www.booking.com#basiclayout
# 14  287.14      1000        clear sky  https://www.booking.com#basiclayout
# 33  289.18       998        clear sky  https://www.booking.com#basiclayout
# 10  286.71      1001        clear sky  https://www.booking.com#basiclayout
# 25  290.13      1000        clear sky  https://www.booking.com#basiclayout
# 18  288.80      1000    broken clouds  https://www.booking.com#basiclayout
# 23  290.47       999    broken clouds  https://www.booking.com#basiclayout
# 4   288.12      1002        clear sky  https://www.booking.com#basiclayout
# 11  286.54      1001        clear sky  https://www.booking.com#basiclayout
# 9   283.27      1001        clear sky  https://www.booking.com#basiclayout
# 12  289.52       999    broken clouds  https://www.booking.com#basiclayout
# 20  289.43       999    broken clouds  https://www.booking.com#basiclayout
# 19  289.52      1001    broken clouds  https://www.booking.com#basiclayout
# 26  292.69      1000    broken clouds  https://www.booking.com#basiclayout
# 21  289.50       999    broken clouds  https://www.booking.com#basiclayout
# 1   287.86      1002  overcast clouds  https://www.booking.com#basiclayout
# 17  285.43      1000  overcast clouds  https://www.booking.com#basiclayout
# 32  289.16       998        clear sky  https://www.booking.com#basiclayout
#
#                                                 House  \
# 2                                   Domaine de Bayeux
# 29                                   dtente sky lodge
# 28                                 Domaine Le Couvent
# 14               Le Luxury Design de la Vieille Ville
# 33                               Villa la Renaissance
# 10  Le Parc - Standing apartments in front of the ...
# 25                CABANE DU SAUNIER MAIA ETANG DU ROY
# 18                                   Le petit atelier
# 23    Nice apartment in Uzès with WiFi and 1 Bedrooms
# 4                    Radisson Blu Hotel, Rouen Centre
# 11                   James Vignoble Hôtel - Eguisheim
# 9                   Les Chambres du Haut-Koenigsbourg
# 12                               Hôtel AKENA BESANCON
# 20             Meininger Marseille Centre la Joliette
# 19  UNE TERRASSE SUR LA MER 4 pers 2 chambres VUE MER
# 26                                    Mas De Calabrun
# 21             TheCamp Hotel&Lodges - Aix en Provence
# 1                     Hôtel Bristol Union Intra Muros
# 17     La Bastide du Calalou; BW Signature Collection
# 32                                    Studio Biarritz
#
#                                           Description Score
# 2   Le Domaine de Bayeux occupe une maison du XVII...   9,4
# 29                Hébergement géré par un particulier   9,4
# 28                       Établissement Voyage Durable   9,3
# 14  Situé à Annecy, à 100 mètres du château et à 2...   9,3
# 33  La Villa la Renaissance propose des chambres à...   9,2
# 10  Offrant une vue sur la ville et doté d'une con...   9,2
# 25                Hébergement géré par un particulier   9,1
# 18                Hébergement géré par un particulier   9,0
# 23  Le Nice apartment in Uzès with WiFi and 1 Bedr...   8,9
# 4   Situé à Rouen, le Radisson Blu Hotel, Rouen Ce...   8,9
# 11  Le James Vignoble Hôtel - Eguisheim vous accue...   8,8
# 9   Situé à Orschwiller, en Alsace, l'établissemen...   8,8
# 12  Situé à Besançon, à 7 km du parc Micropolis, l...   8,7
# 20  Doté d'un bar, d'un salon commun et offrant un...   8,7
# 19  Situé à Cassis, à seulement 100 mètres de Best...   8,7
# 26  Doté d’une piscine extérieure, d’un terrain de...   8,6
# 21                       Établissement Voyage Durable   8,6
# 1   L’Hôtel Bristol Union Intra Muros est situé au...   8,6
# 17                       Établissement Voyage Durable   8,4
# 32                Hébergement géré par un particulier   8,4

# %%
# To Display map with TOP20 hotel's scores 

fig = px.scatter_mapbox(Top20, lat='lat', lon='lon', size = 'temp', opacity=0.4, mapbox_style="carto-positron",color = "Score", zoom=4.5)
fig.show(renderer = "iframe_connected")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_33.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
