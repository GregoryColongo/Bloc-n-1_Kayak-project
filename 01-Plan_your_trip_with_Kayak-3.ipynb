# %% [markdown]
# ![Kayak](https://seekvectorlogo.com/wp-content/uploads/2018/01/kayak-vector-logo.png)
#
# # Plan your trip with Kayak
#
# ## Company's description 📇
#
# <a href="https://www.kayak.com" target="_blank">Kayak</a> is a travel search engine that helps user plan their next trip at the best price.
#
# The company was founded in 2004 by Steve Hafner & Paul M. English. After a few rounds of fundraising, Kayak was acquired by <a href="https://www.bookingholdings.com/" target="_blank">Booking Holdings</a> which now holds:
#
# * <a href="https://booking.com/" target="_blank">Booking.com</a>
# * <a href="https://kayak.com/" target="_blank">Kayak</a>
# * <a href="https://www.priceline.com/" target="_blank">Priceline</a>
# * <a href="https://www.agoda.com/" target="_blank">Agoda</a>
# * <a href="https://Rentalcars.com/" target="_blank">RentalCars</a>
# * <a href="https://www.opentable.com/" target="_blank">OpenTable</a>
#
# With over \$300 million revenue a year, Kayak operates in almost all countries and all languages to help their users book travels accros the globe.

# %% [markdown]
# ## Project 🚧
#
# The marketing team needs help on a new project. After doing some user research, the team discovered that **70% of their users who are planning a trip would like to have more information about the destination they are going to**.
#
# In addition, user research shows that **people tend to be defiant about the information they are reading if they don't know the brand** which produced the content.
#
# Therefore, Kayak Marketing Team would like to create an application that will recommend where people should plan their next holidays. The application should be based on real data about:
#
# * Weather
# * Hotels in the area
#
# The application should then be able to recommend the best destinations and hotels based on the above variables at any given time.

# %% [markdown]
# ## Goals 🎯
#
# As the project has just started, your team doesn't have any data that can be used to create this application. Therefore, your job will be to:
#
# * Scrape data from destinations
# * Get weather data from each destination
# * Get hotels' info about each destination
# * Store all the information above in a data lake
# * Extract, transform and load cleaned data from your datalake to a data warehouse

# %% [markdown]
# ## Scope of this project 🖼️
#
# Marketing team wants to focus first on the best cities to travel to in France. According <a href="https://one-week-in.com/35-cities-to-visit-in-france/" target="_blank">One Week In.com</a> here are the top-35 cities to visit in France:
#
# ```python
# ["Mont Saint Michel",
# "St Malo",
# "Bayeux",
# "Le Havre",
# "Rouen",
# "Paris",
# "Amiens",
# "Lille",
# "Strasbourg",
# "Chateau du Haut Koenigsbourg",
# "Colmar",
# "Eguisheim",
# "Besancon",
# "Dijon",
# "Annecy",
# "Grenoble",
# "Lyon",
# "Gorges du Verdon",
# "Bormes les Mimosas",
# "Cassis",
# "Marseille",
# "Aix en Provence",
# "Avignon",
# "Uzes",
# "Nimes",
# "Aigues Mortes",
# "Saintes Maries de la mer",
# "Collioure",
# "Carcassonne",
# "Ariege",
# "Toulouse",
# "Montauban",
# "Biarritz",
# "Bayonne",
# "La Rochelle"]
# ```
#
# Your team should focus **only on the above cities for your project**.

# %% [markdown]
# ## Helpers 🦮
#
# To help you achieve this project, here are a few tips that should help you
#
# ### Get weather data with an API
#
# *   Use https://nominatim.org/ to get the gps coordinates of all the cities (no subscription required) Documentation : https://nominatim.org/release-docs/develop/api/Search/
#
# *   Use https://openweathermap.org/appid (you have to subscribe to get a free apikey) and https://openweathermap.org/api/one-call-api to get some information about the weather for the 35 cities and put it in a DataFrame
#
# *   Determine the list of cities where the weather will be the nicest within the next 7 days For example, you can use the values of daily.pop and daily.rain to compute the expected volume of rain within the next 7 days... But it's only an example, actually you can have different opinions on a what a nice weather would be like 😎 Maybe the most important criterion for you is the temperature or humidity, so feel free to change the rules !
#
# *   Save all the results in a `.csv` file, you will use it later 😉 You can save all the informations that seem important to you ! Don't forget to save the name of the cities, and also to create a column containing a unique identifier (id) of each city (this is important for what's next in the project)
#
# *   Use plotly to display the best destinations on a map
#
# ### Scrape Booking.com
#
# Since BookingHoldings doesn't have aggregated databases, it will be much faster to scrape data directly from booking.com
#
# You can scrap as many information asyou want, but we suggest that you get at least:
#
# *   hotel name,
# *   Url to its booking.com page,
# *   Its coordinates: latitude and longitude
# *   Score given by the website users
# *   Text description of the hotel
#
#
# ### Create your data lake using S3
#
# Once you managed to build your dataset, you should store into S3 as a csv file.
#
# ### ETL
#
# Once you uploaded your data onto S3, it will be better for the next data analysis team to extract clean data directly from a Data Warehouse. Therefore, create a SQL Database using AWS RDS, extract your data from S3 and store it in your newly created DB.

# %% [markdown]
# ## Deliverable 📬
#
# To complete this project, your team should deliver:
#
# * A `.csv` file in an S3 bucket containing enriched information about weather and hotels for each french city
#
# * A SQL Database where we should be able to get the same cleaned data from S3
#
# * Two maps where you should have a Top-5 destinations and a Top-20 hotels in the area. You can use plotly or any other library to do so. It should look something like this:
#
# ![Map](https://full-stack-assets.s3.eu-west-3.amazonaws.com/images/Kayak_best_destination_project.png)

# %%
#retrieve GPS coordonates

# %%
from bs4 import BeautifulSoup
import requests as r
import pandas as pd
import json

# %%
destination = ["Mont Saint Michel",
"St Malo",
"Bayeux",
"Le Havre",
"Rouen",
"Paris",
"Amiens",
"Lille",
"Strasbourg",
"Chateau du Haut Koenigsbourg",
"Colmar",
"Eguisheim",
"Besancon",
"Dijon",
"Annecy",
"Grenoble",
"Lyon",
"Gorges du Verdon",
"Bormes les Mimosas",
"Cassis",
"Marseille",
"Aix en Provence",
"Avignon",
"Uzes",
"Nimes",
"Aigues Mortes",
"Saintes Maries de la mer",
"Collioure",
"Carcassonne",
"Ariege",
"Toulouse",
"Montauban",
"Biarritz",
"Bayonne",
"La Rochelle"]

# %%
gps=r.get("https://nominatim.openstreetmap.org/search/Mont Saint Michel?format=json&addressdetails=1&limit=1&polygon_svg=0")
gps.text
# Out:
# '[{"place_id":151486647,"licence":"Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright","osm_type":"way","osm_id":211285890,"boundingbox":["48.6349172","48.637031","-1.5133292","-1.5094796"],"lat":"48.6359541","lon":"-1.511459954959514","display_name":"Mont Saint-Michel, Le Mont-Saint-Michel, Avranches, Manche, Normandie, France métropolitaine, 50170, France","class":"place","type":"islet","importance":0.755436556781574,"address":{"place":"Mont Saint-Michel","city":"Le Mont-Saint-Michel","municipality":"Avranches","county":"Manche","state":"Normandie","region":"France métropolitaine","postcode":"50170","country":"France","country_code":"fr"}}]'

# %%
gps.json()
# Out:
# [{'place_id': 151486647,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 211285890,
#   'boundingbox': ['48.6349172', '48.637031', '-1.5133292', '-1.5094796'],
#   'lat': '48.6359541',
#   'lon': '-1.511459954959514',
#   'display_name': 'Mont Saint-Michel, Le Mont-Saint-Michel, Avranches, Manche, Normandie, France métropolitaine, 50170, France',
#   'class': 'place',
#   'type': 'islet',
#   'importance': 0.755436556781574,
#   'address': {'place': 'Mont Saint-Michel',
#    'city': 'Le Mont-Saint-Michel',
#    'municipality': 'Avranches',
#    'county': 'Manche',
#    'state': 'Normandie',
#    'region': 'France métropolitaine',
#    'postcode': '50170',
#    'country': 'France',
#    'country_code': 'fr'}}]

# %%
gps = pd.DataFrame(gps.json())
gps.head()
# Out:
#     place_id                                            licence osm_type  \
# 0  151486647  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
#
#       osm_id                                      boundingbox         lat  \
# 0  211285890  [48.6349172, 48.637031, -1.5133292, -1.5094796]  48.6359541
#
#                   lon                                       display_name  \
# 0  -1.511459954959514  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...
#
#    class   type  importance                                            address
# 0  place  islet    0.755437  {'place': 'Mont Saint-Michel', 'city': 'Le Mon...

# %%
# A quoi sert le fstring dans cette boucle ?
for i in destination:
    response = r.get(f'https://nominatim.openstreetmap.org/search/{i}/FR?format=json&addressdetails=1&limit=1&polygon_svg=1')
    gps = gps.append(response.json(), ignore_index=True)

# %%
gps.head()
# Out:
#     place_id                                            licence osm_type  \
# 0  151486647  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 1  151486647  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 2     121999  Data © OpenStreetMap contributors, ODbL 1.0. h...     node
# 3    3126290  Data © OpenStreetMap contributors, ODbL 1.0. h...     node
# 4   17564290  Data © OpenStreetMap contributors, ODbL 1.0. h...     node
#
#        osm_id                                       boundingbox         lat  \
# 0   211285890   [48.6349172, 48.637031, -1.5133292, -1.5094796]  48.6359541
# 1   211285890   [48.6349172, 48.637031, -1.5133292, -1.5094796]  48.6359541
# 2    26691521    [48.609518, 48.689518, -2.0660409, -1.9860409]   48.649518
# 3   409700749  [49.2364624, 49.3164624, -0.7424738, -0.6624738]  49.2764624
# 4  1909836591   [49.3338975, 49.6538975, -0.0520268, 0.2679732]  49.4938975
#
#                   lon                                       display_name  \
# 0  -1.511459954959514  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...
# 1  -1.511459954959514  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...
# 2          -2.0260409  Saint-Malo, Ille-et-Vilaine, Bretagne, France ...
# 3          -0.7024738  Bayeux, Calvados, Normandie, France métropolit...
# 4           0.1079732  Le Havre, Seine-Maritime, Normandie, France mé...
#
#    class   type  importance  \
# 0  place  islet    0.755437
# 1  place  islet    0.855437
# 2  place   town    0.776467
# 3  place   town    0.782700
# 4  place   city    0.922333
#
#                                              address  \
# 0  {'place': 'Mont Saint-Michel', 'city': 'Le Mon...
# 1  {'place': 'Mont Saint-Michel', 'city': 'Le Mon...
# 2  {'town': 'Saint-Malo', 'city': 'Saint-Malo', '...
# 3  {'town': 'Bayeux', 'city': 'Bayeux', 'municipa...
# 4  {'city': 'Le Havre', 'municipality': 'Le Havre...
#
#                                                  svg  \
# 0                                                NaN
# 1  M -1.5133292 -48.636198 L -1.5133291 -48.63618...
# 2                    cx="-2.0260409" cy="-48.649518"
# 3                   cx="-0.7024738" cy="-49.2764624"
# 4                    cx="0.1079732" cy="-49.4938975"
#
#                                                 icon
# 0                                                NaN
# 1                                                NaN
# 2  https://nominatim.openstreetmap.org/ui/mapicon...
# 3  https://nominatim.openstreetmap.org/ui/mapicon...
# 4  https://nominatim.openstreetmap.org/ui/mapicon...

# %%
# to be sure to get the 35 places after data rame transformation
gps.shape
# Out:
# (36, 14)

# %%
#remove the first row
gps =gps.drop(0)
gps
# Out:
#      place_id                                            licence  osm_type  \
# 1   151486647  Data © OpenStreetMap contributors, ODbL 1.0. h...       way
# 2      121999  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 3     3126290  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 4    17564290  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 5   281721777  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 6   281739181  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 7   281746639  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 8   282028769  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 9      121990  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 10  117144990  Data © OpenStreetMap contributors, ODbL 1.0. h...       way
# 11  281826068  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 12  282202896  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 13     122417  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 14     120864  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 15     121462  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 16     123256  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 17  281934488  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 18   77029462  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 19  282091180  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 20  281762295  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 21     124969  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 22     126708  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 23  281857541  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 24  282263463  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 25     122444  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 26     122788  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 27     125804  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 28     129118  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 29     126816  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 30  281653603  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 31     121019  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 32   26251971  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 33   15759375  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 34   15548981  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 35     123543  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
#
#         osm_id                                       boundingbox  \
# 1    211285890   [48.6349172, 48.637031, -1.5133292, -1.5094796]
# 2     26691521    [48.609518, 48.689518, -2.0660409, -1.9860409]
# 3    409700749  [49.2364624, 49.3164624, -0.7424738, -0.6624738]
# 4   1909836591   [49.3338975, 49.6538975, -0.0520268, 0.2679732]
# 5        75628    [49.4172001, 49.4652601, 1.0300648, 1.1521157]
# 6         7444      [48.8155755, 48.902156, 2.224122, 2.4697602]
# 7       114347     [49.846837, 49.9505487, 2.2235574, 2.3457767]
# 8        58404     [50.6008264, 50.6612596, 2.9679677, 3.125725]
# 9     26686563      [48.424614, 48.744614, 7.5907127, 7.9107127]
# 10    61044809     [48.249302, 48.2496794, 7.3436964, 7.3449443]
# 11       61423      [48.0407053, 48.182062, 7.3154803, 7.469167]
# 12       79442     [48.0240327, 48.0515072, 7.2412792, 7.351854]
# 13    26686554    [47.0780222, 47.3980222, 5.8643622, 6.1843622]
# 14    26686504    [47.1615806, 47.4815806, 4.8814701, 5.2014701]
# 15    26692465    [45.7392348, 46.0592348, 5.9688847, 6.2888847]
# 16    26686589    [45.0275602, 45.3475602, 5.5757819, 5.8957819]
# 17      120965    [45.7073666, 45.8082628, 4.7718134, 4.8983774]
# 18  7193513219    [43.7496062, 43.7497062, 6.3285116, 6.3286116]
# 19     1118915    [43.0864271, 43.2278201, 6.2716142, 6.4514893]
# 20       76425    [43.1884732, 43.2487231, 5.5063193, 5.5945199]
# 21    26761400    [43.1361743, 43.4561743, 5.2099525, 5.5299525]
# 22    26686595    [43.3698424, 43.6898424, 5.2874738, 5.6074738]
# 23      102478    [43.8866543, 43.9967419, 4.7396309, 4.9271468]
# 24      380050    [43.9811093, 44.0765914, 4.3852299, 4.4467859]
# 25    26686585    [43.6774249, 43.9974249, 4.2000687, 4.5200687]
# 26    26696517    [43.5458225, 43.5858225, 4.1712837, 4.2112837]
# 27    26696399    [43.4322771, 43.4722771, 4.4087172, 4.4487172]
# 28    26698499        [42.50505, 42.54505, 3.0631554, 3.1031554]
# 29    26691834    [43.1730358, 43.2530358, 2.3091069, 2.3891069]
# 30        7439    [42.5732416, 43.3162514, 0.8267506, 2.1758135]
# 31    26686518    [43.4444622, 43.7644622, 1.2842469, 1.6042469]
# 32  2725062491    [43.9775835, 44.0575835, 1.3149991, 1.3949991]
# 33  1690923732  [43.4432523, 43.5232523, -1.5992776, -1.5192776]
# 34  1690923675    [43.4533379, 43.5333379, -1.515099, -1.435099]
# 35    26691694  [45.9991126, 46.3191126, -1.3120434, -0.9920434]
#
#                    lat                 lon  \
# 1           48.6359541  -1.511459954959514
# 2            48.649518          -2.0260409
# 3           49.2764624          -0.7024738
# 4           49.4938975           0.1079732
# 5           49.4404591           1.0939658
# 6           48.8588897  2.3200410217200766
# 7           49.8941708           2.2956951
# 8           50.6365654           3.0635282
# 9            48.584614           7.7507127
# 10  48.249489800000006    7.34429620253195
# 11  48.111095000000006   7.363622702110888
# 12          48.0377622   7.317521300603902
# 13          47.2380222           6.0243622
# 14          47.3215806           5.0414701
# 15          45.8992348           6.1288847
# 16          45.1875602           5.7357819
# 17          45.7578137           4.8320114
# 18          43.7496562           6.3285616
# 19          43.1506968           6.3419285
# 20          43.2181778   5.553394005675274
# 21          43.2961743           5.3699525
# 22          43.5298424           5.4474738
# 23          43.9492493           4.8059012
# 24         44.02856055   4.420493673910444
# 25          43.8374249           4.3600687
# 26          43.5658225           4.1912837
# 27          43.4522771           4.4287172
# 28            42.52505           3.0831554
# 29          43.2130358           2.3491069
# 30          42.9455368  1.4065544156065486
# 31          43.6044622           1.4442469
# 32          44.0175835           1.3549991
# 33          43.4832523          -1.5592776
# 34          43.4933379           -1.475099
# 35          46.1591126          -1.1520434
#
#                                          display_name     class  \
# 1   Mont Saint-Michel, Le Mont-Saint-Michel, Avran...     place
# 2   Saint-Malo, Ille-et-Vilaine, Bretagne, France ...     place
# 3   Bayeux, Calvados, Normandie, France métropolit...     place
# 4   Le Havre, Seine-Maritime, Normandie, France mé...     place
# 5   Rouen, Seine-Maritime, Normandie, France métro...  boundary
# 6   Paris, Île-de-France, France métropolitaine, F...  boundary
# 7   Amiens, Somme, Hauts-de-France, France métropo...  boundary
# 8   Lille, Nord, Hauts-de-France, France métropoli...  boundary
# 9   Strasbourg, Bas-Rhin, Grand Est, France métrop...     place
# 10  Château du Haut-Kœnigsbourg, Chemin fermé suit...  historic
# 11  Colmar, Colmar-Ribeauvillé, Haut-Rhin, Grand E...  boundary
# 12  Eguisheim, Colmar-Ribeauvillé, Haut-Rhin, Gran...  boundary
# 13  Besançon, Doubs, Bourgogne-Franche-Comté, Fran...     place
# 14  Dijon, Côte-d'Or, Bourgogne-Franche-Comté, Fra...     place
# 15  Annecy, Haute-Savoie, Auvergne-Rhône-Alpes, Fr...     place
# 16  Grenoble, Isère, Auvergne-Rhône-Alpes, France ...     place
# 17  Lyon, Métropole de Lyon, Circonscription dépar...  boundary
# 18  Gorges du Verdon, Route des Crêtes, Les Ferrai...   tourism
# 19  Bormes-les-Mimosas, Toulon, Var, Provence-Alpe...  boundary
# 20  Cassis, Marseille, Bouches-du-Rhône, Provence-...  boundary
# 21  Marseille, Bouches-du-Rhône, Provence-Alpes-Cô...     place
# 22  Aix-en-Provence, Bouches-du-Rhône, Provence-Al...     place
# 23  Avignon, Vaucluse, Provence-Alpes-Côte d'Azur,...  boundary
# 24  Uzès, Nîmes, Gard, Occitanie, France métropoli...  boundary
# 25  Nîmes, Gard, Occitanie, France métropolitaine,...     place
# 26  Aigues-Mortes, Nîmes, Gard, Occitanie, France ...     place
# 27  Saintes-Maries-de-la-Mer, Arles, Bouches-du-Rh...     place
# 28  Collioure, Céret, Pyrénées-Orientales, Occitan...     place
# 29  Carcassonne, Aude, Occitanie, France métropoli...     place
# 30   Ariège, Occitanie, France métropolitaine, France  boundary
# 31  Toulouse, Haute-Garonne, Occitanie, France mét...     place
# 32  Montauban, Tarn-et-Garonne, Occitanie, France ...     place
# 33  Biarritz, Bayonne, Pyrénées-Atlantiques, Nouve...     place
# 34  Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquita...     place
# 35  La Rochelle, Charente-Maritime, Nouvelle-Aquit...     place
#
#               type  importance  \
# 1            islet    0.855437
# 2             town    0.776467
# 3             town    0.782700
# 4             city    0.922333
# 5   administrative    0.850073
# 6   administrative    1.041710
# 7   administrative    0.834949
# 8   administrative    0.863204
# 9             city    0.884805
# 10          castle    0.653955
# 11  administrative    0.680909
# 12  administrative    0.734972
# 13            city    0.718351
# 14            city    0.843619
# 15            city    0.789077
# 16            city    0.851809
# 17  administrative    0.901378
# 18      attraction    0.778150
# 19  administrative    0.877316
# 20  administrative    0.686780
# 21            city    0.891377
# 22            city    0.991085
# 23  administrative    0.832094
# 24  administrative    0.637533
# 25            city    0.703055
# 26         village    0.832380
# 27         village    1.072517
# 28         village    0.718409
# 29            town    0.799167
# 30  administrative    0.700911
# 31            city    0.878214
# 32            town    0.764248
# 33            town    0.789612
# 34            town    0.812780
# 35            city    0.901484
#
#                                               address  \
# 1   {'place': 'Mont Saint-Michel', 'city': 'Le Mon...
# 2   {'town': 'Saint-Malo', 'city': 'Saint-Malo', '...
# 3   {'town': 'Bayeux', 'city': 'Bayeux', 'municipa...
# 4   {'city': 'Le Havre', 'municipality': 'Le Havre...
# 5   {'city': 'Rouen', 'municipality': 'Rouen', 'co...
# 6   {'suburb': 'Paris', 'city_district': 'Paris', ...
# 7   {'city': 'Amiens', 'municipality': 'Amiens', '...
# 8   {'city': 'Lille', 'municipality': 'Lille', 'co...
# 9   {'city': 'Strasbourg', 'municipality': 'Strasb...
# 10  {'historic': 'Château du Haut-Kœnigsbourg', 'r...
# 11  {'city': 'Colmar', 'municipality': 'Colmar-Rib...
# 12  {'city': 'Eguisheim', 'municipality': 'Colmar-...
# 13  {'city': 'Besançon', 'municipality': 'Besançon...
# 14  {'city': 'Dijon', 'municipality': 'Dijon', 'co...
# 15  {'city': 'Annecy', 'municipality': 'Annecy', '...
# 16  {'city': 'Grenoble', 'municipality': 'Grenoble...
# 17  {'city': 'Lyon', 'municipality': 'Lyon', 'coun...
# 18  {'tourism': 'Gorges du Verdon', 'road': 'Route...
# 19  {'village': 'Bormes-les-Mimosas', 'municipalit...
# 20  {'city': 'Cassis', 'municipality': 'Marseille'...
# 21  {'city': 'Marseille', 'municipality': 'Marseil...
# 22  {'city': 'Aix-en-Provence', 'municipality': 'A...
# 23  {'city': 'Avignon', 'municipality': 'Avignon',...
# 24  {'city': 'Uzès', 'municipality': 'Nîmes', 'cou...
# 25  {'city': 'Nîmes', 'municipality': 'Nîmes', 'co...
# 26  {'village': 'Aigues-Mortes', 'city': 'Aigues-M...
# 27  {'village': 'Saintes-Maries-de-la-Mer', 'city'...
# 28  {'village': 'Collioure', 'city': 'Collioure', ...
# 29  {'town': 'Carcassonne', 'city': 'Carcassonne',...
# 30  {'county': 'Ariège', 'state': 'Occitanie', 're...
# 31  {'city': 'Toulouse', 'municipality': 'Toulouse...
# 32  {'town': 'Montauban', 'city': 'Montauban', 'mu...
# 33  {'town': 'Biarritz', 'city': 'Biarritz', 'muni...
# 34  {'town': 'Bayonne', 'city': 'Bayonne', 'munici...
# 35  {'city': 'La Rochelle', 'municipality': 'La Ro...
#
#                                                   svg  \
# 1   M -1.5133292 -48.636198 L -1.5133291 -48.63618...
# 2                     cx="-2.0260409" cy="-48.649518"
# 3                    cx="-0.7024738" cy="-49.2764624"
# 4                     cx="0.1079732" cy="-49.4938975"
# 5   M 1.0300648 -49.4323649 L 1.0306589 -49.432081...
# 6   M 2.224122 -48.854199 L 2.224125 -48.85402 2.2...
# 7   M 2.2235574 -49.9026001 L 2.224849 -49.9017275...
# 8   M 2.9679677 -50.6350914 L 2.9696046 -50.633589...
# 9                      cx="7.7507127" cy="-48.584614"
# 10  M 7.3436964 -48.2495766 L 7.3437155 -48.249525...
# 11  M 7.3154803 -48.0701735 L 7.3206759 -48.069566...
# 12  M 7.2412792 -48.0333617 L 7.2416374 -48.032471...
# 13                    cx="6.0243622" cy="-47.2380222"
# 14                    cx="5.0414701" cy="-47.3215806"
# 15                    cx="6.1288847" cy="-45.8992348"
# 16                    cx="5.7357819" cy="-45.1875602"
# 17  M 4.7718134 -45.7510347 L 4.7718216 -45.751021...
# 18                    cx="6.3285616" cy="-43.7496562"
# 19  M 6.2716142 -43.1211721 L 6.2729037 -43.121188...
# 20  M 5.5063193 -43.2302652 L 5.5063276 -43.230190...
# 21                    cx="5.3699525" cy="-43.2961743"
# 22                    cx="5.4474738" cy="-43.5298424"
# 23  M 4.7396309 -43.9245884 L 4.7433944 -43.923450...
# 24  M 4.3852299 -43.9899665 L 4.3876287 -43.988473...
# 25                    cx="4.3600687" cy="-43.8374249"
# 26                    cx="4.1912837" cy="-43.5658225"
# 27                    cx="4.4287172" cy="-43.4522771"
# 28                      cx="3.0831554" cy="-42.52505"
# 29                    cx="2.3491069" cy="-43.2130358"
# 30  M 0.8267506 -42.9141974 L 0.8267926 -42.914061...
# 31                    cx="1.4442469" cy="-43.6044622"
# 32                    cx="1.3549991" cy="-44.0175835"
# 33                   cx="-1.5592776" cy="-43.4832523"
# 34                    cx="-1.475099" cy="-43.4933379"
# 35                   cx="-1.1520434" cy="-46.1591126"
#
#                                                  icon
# 1                                                 NaN
# 2   https://nominatim.openstreetmap.org/ui/mapicon...
# 3   https://nominatim.openstreetmap.org/ui/mapicon...
# 4   https://nominatim.openstreetmap.org/ui/mapicon...
# 5   https://nominatim.openstreetmap.org/ui/mapicon...
# 6   https://nominatim.openstreetmap.org/ui/mapicon...
# 7   https://nominatim.openstreetmap.org/ui/mapicon...
# 8   https://nominatim.openstreetmap.org/ui/mapicon...
# 9   https://nominatim.openstreetmap.org/ui/mapicon...
# 10  https://nominatim.openstreetmap.org/ui/mapicon...
# 11  https://nominatim.openstreetmap.org/ui/mapicon...
# 12  https://nominatim.openstreetmap.org/ui/mapicon...
# 13  https://nominatim.openstreetmap.org/ui/mapicon...
# 14  https://nominatim.openstreetmap.org/ui/mapicon...
# 15  https://nominatim.openstreetmap.org/ui/mapicon...
# 16  https://nominatim.openstreetmap.org/ui/mapicon...
# 17  https://nominatim.openstreetmap.org/ui/mapicon...
# 18  https://nominatim.openstreetmap.org/ui/mapicon...
# 19  https://nominatim.openstreetmap.org/ui/mapicon...
# 20  https://nominatim.openstreetmap.org/ui/mapicon...
# 21  https://nominatim.openstreetmap.org/ui/mapicon...
# 22  https://nominatim.openstreetmap.org/ui/mapicon...
# 23  https://nominatim.openstreetmap.org/ui/mapicon...
# 24  https://nominatim.openstreetmap.org/ui/mapicon...
# 25  https://nominatim.openstreetmap.org/ui/mapicon...
# 26  https://nominatim.openstreetmap.org/ui/mapicon...
# 27  https://nominatim.openstreetmap.org/ui/mapicon...
# 28  https://nominatim.openstreetmap.org/ui/mapicon...
# 29  https://nominatim.openstreetmap.org/ui/mapicon...
# 30  https://nominatim.openstreetmap.org/ui/mapicon...
# 31  https://nominatim.openstreetmap.org/ui/mapicon...
# 32  https://nominatim.openstreetmap.org/ui/mapicon...
# 33  https://nominatim.openstreetmap.org/ui/mapicon...
# 34  https://nominatim.openstreetmap.org/ui/mapicon...
# 35  https://nominatim.openstreetmap.org/ui/mapicon...

# %%
#adding of destination with lat and lon
gps['destination'] = destination
display(gps)
# Out:
#      place_id                                            licence  osm_type  \
# 1   151486647  Data © OpenStreetMap contributors, ODbL 1.0. h...       way
# 2      121999  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 3     3126290  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 4    17564290  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 5   281721777  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 6   281739181  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 7   281746639  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 8   282028769  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 9      121990  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 10  117144990  Data © OpenStreetMap contributors, ODbL 1.0. h...       way
# 11  281826068  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 12  282202896  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 13     122417  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 14     120864  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 15     121462  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 16     123256  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 17  281934488  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 18   77029462  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 19  282091180  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 20  281762295  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 21     124969  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 22     126708  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 23  281857541  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 24  282263463  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 25     122444  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 26     122788  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 27     125804  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 28     129118  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 29     126816  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 30  281653603  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 31     121019  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 32   26251971  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 33   15759375  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 34   15548981  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 35     123543  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
#
#         osm_id                                       boundingbox  \
# 1    211285890   [48.6349172, 48.637031, -1.5133292, -1.5094796]
# 2     26691521    [48.609518, 48.689518, -2.0660409, -1.9860409]
# 3    409700749  [49.2364624, 49.3164624, -0.7424738, -0.6624738]
# 4   1909836591   [49.3338975, 49.6538975, -0.0520268, 0.2679732]
# 5        75628    [49.4172001, 49.4652601, 1.0300648, 1.1521157]
# 6         7444      [48.8155755, 48.902156, 2.224122, 2.4697602]
# 7       114347     [49.846837, 49.9505487, 2.2235574, 2.3457767]
# 8        58404     [50.6008264, 50.6612596, 2.9679677, 3.125725]
# 9     26686563      [48.424614, 48.744614, 7.5907127, 7.9107127]
# 10    61044809     [48.249302, 48.2496794, 7.3436964, 7.3449443]
# 11       61423      [48.0407053, 48.182062, 7.3154803, 7.469167]
# 12       79442     [48.0240327, 48.0515072, 7.2412792, 7.351854]
# 13    26686554    [47.0780222, 47.3980222, 5.8643622, 6.1843622]
# 14    26686504    [47.1615806, 47.4815806, 4.8814701, 5.2014701]
# 15    26692465    [45.7392348, 46.0592348, 5.9688847, 6.2888847]
# 16    26686589    [45.0275602, 45.3475602, 5.5757819, 5.8957819]
# 17      120965    [45.7073666, 45.8082628, 4.7718134, 4.8983774]
# 18  7193513219    [43.7496062, 43.7497062, 6.3285116, 6.3286116]
# 19     1118915    [43.0864271, 43.2278201, 6.2716142, 6.4514893]
# 20       76425    [43.1884732, 43.2487231, 5.5063193, 5.5945199]
# 21    26761400    [43.1361743, 43.4561743, 5.2099525, 5.5299525]
# 22    26686595    [43.3698424, 43.6898424, 5.2874738, 5.6074738]
# 23      102478    [43.8866543, 43.9967419, 4.7396309, 4.9271468]
# 24      380050    [43.9811093, 44.0765914, 4.3852299, 4.4467859]
# 25    26686585    [43.6774249, 43.9974249, 4.2000687, 4.5200687]
# 26    26696517    [43.5458225, 43.5858225, 4.1712837, 4.2112837]
# 27    26696399    [43.4322771, 43.4722771, 4.4087172, 4.4487172]
# 28    26698499        [42.50505, 42.54505, 3.0631554, 3.1031554]
# 29    26691834    [43.1730358, 43.2530358, 2.3091069, 2.3891069]
# 30        7439    [42.5732416, 43.3162514, 0.8267506, 2.1758135]
# 31    26686518    [43.4444622, 43.7644622, 1.2842469, 1.6042469]
# 32  2725062491    [43.9775835, 44.0575835, 1.3149991, 1.3949991]
# 33  1690923732  [43.4432523, 43.5232523, -1.5992776, -1.5192776]
# 34  1690923675    [43.4533379, 43.5333379, -1.515099, -1.435099]
# 35    26691694  [45.9991126, 46.3191126, -1.3120434, -0.9920434]
#
#                    lat                 lon  \
# 1           48.6359541  -1.511459954959514
# 2            48.649518          -2.0260409
# 3           49.2764624          -0.7024738
# 4           49.4938975           0.1079732
# 5           49.4404591           1.0939658
# 6           48.8588897  2.3200410217200766
# 7           49.8941708           2.2956951
# 8           50.6365654           3.0635282
# 9            48.584614           7.7507127
# 10  48.249489800000006    7.34429620253195
# 11  48.111095000000006   7.363622702110888
# 12          48.0377622   7.317521300603902
# 13          47.2380222           6.0243622
# 14          47.3215806           5.0414701
# 15          45.8992348           6.1288847
# 16          45.1875602           5.7357819
# 17          45.7578137           4.8320114
# 18          43.7496562           6.3285616
# 19          43.1506968           6.3419285
# 20          43.2181778   5.553394005675274
# 21          43.2961743           5.3699525
# 22          43.5298424           5.4474738
# 23          43.9492493           4.8059012
# 24         44.02856055   4.420493673910444
# 25          43.8374249           4.3600687
# 26          43.5658225           4.1912837
# 27          43.4522771           4.4287172
# 28            42.52505           3.0831554
# 29          43.2130358           2.3491069
# 30          42.9455368  1.4065544156065486
# 31          43.6044622           1.4442469
# 32          44.0175835           1.3549991
# 33          43.4832523          -1.5592776
# 34          43.4933379           -1.475099
# 35          46.1591126          -1.1520434
#
#                                          display_name     class  \
# 1   Mont Saint-Michel, Le Mont-Saint-Michel, Avran...     place
# 2   Saint-Malo, Ille-et-Vilaine, Bretagne, France ...     place
# 3   Bayeux, Calvados, Normandie, France métropolit...     place
# 4   Le Havre, Seine-Maritime, Normandie, France mé...     place
# 5   Rouen, Seine-Maritime, Normandie, France métro...  boundary
# 6   Paris, Île-de-France, France métropolitaine, F...  boundary
# 7   Amiens, Somme, Hauts-de-France, France métropo...  boundary
# 8   Lille, Nord, Hauts-de-France, France métropoli...  boundary
# 9   Strasbourg, Bas-Rhin, Grand Est, France métrop...     place
# 10  Château du Haut-Kœnigsbourg, Chemin fermé suit...  historic
# 11  Colmar, Colmar-Ribeauvillé, Haut-Rhin, Grand E...  boundary
# 12  Eguisheim, Colmar-Ribeauvillé, Haut-Rhin, Gran...  boundary
# 13  Besançon, Doubs, Bourgogne-Franche-Comté, Fran...     place
# 14  Dijon, Côte-d'Or, Bourgogne-Franche-Comté, Fra...     place
# 15  Annecy, Haute-Savoie, Auvergne-Rhône-Alpes, Fr...     place
# 16  Grenoble, Isère, Auvergne-Rhône-Alpes, France ...     place
# 17  Lyon, Métropole de Lyon, Circonscription dépar...  boundary
# 18  Gorges du Verdon, Route des Crêtes, Les Ferrai...   tourism
# 19  Bormes-les-Mimosas, Toulon, Var, Provence-Alpe...  boundary
# 20  Cassis, Marseille, Bouches-du-Rhône, Provence-...  boundary
# 21  Marseille, Bouches-du-Rhône, Provence-Alpes-Cô...     place
# 22  Aix-en-Provence, Bouches-du-Rhône, Provence-Al...     place
# 23  Avignon, Vaucluse, Provence-Alpes-Côte d'Azur,...  boundary
# 24  Uzès, Nîmes, Gard, Occitanie, France métropoli...  boundary
# 25  Nîmes, Gard, Occitanie, France métropolitaine,...     place
# 26  Aigues-Mortes, Nîmes, Gard, Occitanie, France ...     place
# 27  Saintes-Maries-de-la-Mer, Arles, Bouches-du-Rh...     place
# 28  Collioure, Céret, Pyrénées-Orientales, Occitan...     place
# 29  Carcassonne, Aude, Occitanie, France métropoli...     place
# 30   Ariège, Occitanie, France métropolitaine, France  boundary
# 31  Toulouse, Haute-Garonne, Occitanie, France mét...     place
# 32  Montauban, Tarn-et-Garonne, Occitanie, France ...     place
# 33  Biarritz, Bayonne, Pyrénées-Atlantiques, Nouve...     place
# 34  Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquita...     place
# 35  La Rochelle, Charente-Maritime, Nouvelle-Aquit...     place
#
#               type  importance  \
# 1            islet    0.855437
# 2             town    0.776467
# 3             town    0.782700
# 4             city    0.922333
# 5   administrative    0.850073
# 6   administrative    1.041710
# 7   administrative    0.834949
# 8   administrative    0.863204
# 9             city    0.884805
# 10          castle    0.653955
# 11  administrative    0.680909
# 12  administrative    0.734972
# 13            city    0.718351
# 14            city    0.843619
# 15            city    0.789077
# 16            city    0.851809
# 17  administrative    0.901378
# 18      attraction    0.778150
# 19  administrative    0.877316
# 20  administrative    0.686780
# 21            city    0.891377
# 22            city    0.991085
# 23  administrative    0.832094
# 24  administrative    0.637533
# 25            city    0.703055
# 26         village    0.832380
# 27         village    1.072517
# 28         village    0.718409
# 29            town    0.799167
# 30  administrative    0.700911
# 31            city    0.878214
# 32            town    0.764248
# 33            town    0.789612
# 34            town    0.812780
# 35            city    0.901484
#
#                                               address  \
# 1   {'place': 'Mont Saint-Michel', 'city': 'Le Mon...
# 2   {'town': 'Saint-Malo', 'city': 'Saint-Malo', '...
# 3   {'town': 'Bayeux', 'city': 'Bayeux', 'municipa...
# 4   {'city': 'Le Havre', 'municipality': 'Le Havre...
# 5   {'city': 'Rouen', 'municipality': 'Rouen', 'co...
# 6   {'suburb': 'Paris', 'city_district': 'Paris', ...
# 7   {'city': 'Amiens', 'municipality': 'Amiens', '...
# 8   {'city': 'Lille', 'municipality': 'Lille', 'co...
# 9   {'city': 'Strasbourg', 'municipality': 'Strasb...
# 10  {'historic': 'Château du Haut-Kœnigsbourg', 'r...
# 11  {'city': 'Colmar', 'municipality': 'Colmar-Rib...
# 12  {'city': 'Eguisheim', 'municipality': 'Colmar-...
# 13  {'city': 'Besançon', 'municipality': 'Besançon...
# 14  {'city': 'Dijon', 'municipality': 'Dijon', 'co...
# 15  {'city': 'Annecy', 'municipality': 'Annecy', '...
# 16  {'city': 'Grenoble', 'municipality': 'Grenoble...
# 17  {'city': 'Lyon', 'municipality': 'Lyon', 'coun...
# 18  {'tourism': 'Gorges du Verdon', 'road': 'Route...
# 19  {'village': 'Bormes-les-Mimosas', 'municipalit...
# 20  {'city': 'Cassis', 'municipality': 'Marseille'...
# 21  {'city': 'Marseille', 'municipality': 'Marseil...
# 22  {'city': 'Aix-en-Provence', 'municipality': 'A...
# 23  {'city': 'Avignon', 'municipality': 'Avignon',...
# 24  {'city': 'Uzès', 'municipality': 'Nîmes', 'cou...
# 25  {'city': 'Nîmes', 'municipality': 'Nîmes', 'co...
# 26  {'village': 'Aigues-Mortes', 'city': 'Aigues-M...
# 27  {'village': 'Saintes-Maries-de-la-Mer', 'city'...
# 28  {'village': 'Collioure', 'city': 'Collioure', ...
# 29  {'town': 'Carcassonne', 'city': 'Carcassonne',...
# 30  {'county': 'Ariège', 'state': 'Occitanie', 're...
# 31  {'city': 'Toulouse', 'municipality': 'Toulouse...
# 32  {'town': 'Montauban', 'city': 'Montauban', 'mu...
# 33  {'town': 'Biarritz', 'city': 'Biarritz', 'muni...
# 34  {'town': 'Bayonne', 'city': 'Bayonne', 'munici...
# 35  {'city': 'La Rochelle', 'municipality': 'La Ro...
#
#                                                   svg  \
# 1   M -1.5133292 -48.636198 L -1.5133291 -48.63618...
# 2                     cx="-2.0260409" cy="-48.649518"
# 3                    cx="-0.7024738" cy="-49.2764624"
# 4                     cx="0.1079732" cy="-49.4938975"
# 5   M 1.0300648 -49.4323649 L 1.0306589 -49.432081...
# 6   M 2.224122 -48.854199 L 2.224125 -48.85402 2.2...
# 7   M 2.2235574 -49.9026001 L 2.224849 -49.9017275...
# 8   M 2.9679677 -50.6350914 L 2.9696046 -50.633589...
# 9                      cx="7.7507127" cy="-48.584614"
# 10  M 7.3436964 -48.2495766 L 7.3437155 -48.249525...
# 11  M 7.3154803 -48.0701735 L 7.3206759 -48.069566...
# 12  M 7.2412792 -48.0333617 L 7.2416374 -48.032471...
# 13                    cx="6.0243622" cy="-47.2380222"
# 14                    cx="5.0414701" cy="-47.3215806"
# 15                    cx="6.1288847" cy="-45.8992348"
# 16                    cx="5.7357819" cy="-45.1875602"
# 17  M 4.7718134 -45.7510347 L 4.7718216 -45.751021...
# 18                    cx="6.3285616" cy="-43.7496562"
# 19  M 6.2716142 -43.1211721 L 6.2729037 -43.121188...
# 20  M 5.5063193 -43.2302652 L 5.5063276 -43.230190...
# 21                    cx="5.3699525" cy="-43.2961743"
# 22                    cx="5.4474738" cy="-43.5298424"
# 23  M 4.7396309 -43.9245884 L 4.7433944 -43.923450...
# 24  M 4.3852299 -43.9899665 L 4.3876287 -43.988473...
# 25                    cx="4.3600687" cy="-43.8374249"
# 26                    cx="4.1912837" cy="-43.5658225"
# 27                    cx="4.4287172" cy="-43.4522771"
# 28                      cx="3.0831554" cy="-42.52505"
# 29                    cx="2.3491069" cy="-43.2130358"
# 30  M 0.8267506 -42.9141974 L 0.8267926 -42.914061...
# 31                    cx="1.4442469" cy="-43.6044622"
# 32                    cx="1.3549991" cy="-44.0175835"
# 33                   cx="-1.5592776" cy="-43.4832523"
# 34                    cx="-1.475099" cy="-43.4933379"
# 35                   cx="-1.1520434" cy="-46.1591126"
#
#                                                  icon  \
# 1                                                 NaN
# 2   https://nominatim.openstreetmap.org/ui/mapicon...
# 3   https://nominatim.openstreetmap.org/ui/mapicon...
# 4   https://nominatim.openstreetmap.org/ui/mapicon...
# 5   https://nominatim.openstreetmap.org/ui/mapicon...
# 6   https://nominatim.openstreetmap.org/ui/mapicon...
# 7   https://nominatim.openstreetmap.org/ui/mapicon...
# 8   https://nominatim.openstreetmap.org/ui/mapicon...
# 9   https://nominatim.openstreetmap.org/ui/mapicon...
# 10  https://nominatim.openstreetmap.org/ui/mapicon...
# 11  https://nominatim.openstreetmap.org/ui/mapicon...
# 12  https://nominatim.openstreetmap.org/ui/mapicon...
# 13  https://nominatim.openstreetmap.org/ui/mapicon...
# 14  https://nominatim.openstreetmap.org/ui/mapicon...
# 15  https://nominatim.openstreetmap.org/ui/mapicon...
# 16  https://nominatim.openstreetmap.org/ui/mapicon...
# 17  https://nominatim.openstreetmap.org/ui/mapicon...
# 18  https://nominatim.openstreetmap.org/ui/mapicon...
# 19  https://nominatim.openstreetmap.org/ui/mapicon...
# 20  https://nominatim.openstreetmap.org/ui/mapicon...
# 21  https://nominatim.openstreetmap.org/ui/mapicon...
# 22  https://nominatim.openstreetmap.org/ui/mapicon...
# 23  https://nominatim.openstreetmap.org/ui/mapicon...
# 24  https://nominatim.openstreetmap.org/ui/mapicon...
# 25  https://nominatim.openstreetmap.org/ui/mapicon...
# 26  https://nominatim.openstreetmap.org/ui/mapicon...
# 27  https://nominatim.openstreetmap.org/ui/mapicon...
# 28  https://nominatim.openstreetmap.org/ui/mapicon...
# 29  https://nominatim.openstreetmap.org/ui/mapicon...
# 30  https://nominatim.openstreetmap.org/ui/mapicon...
# 31  https://nominatim.openstreetmap.org/ui/mapicon...
# 32  https://nominatim.openstreetmap.org/ui/mapicon...
# 33  https://nominatim.openstreetmap.org/ui/mapicon...
# 34  https://nominatim.openstreetmap.org/ui/mapicon...
# 35  https://nominatim.openstreetmap.org/ui/mapicon...
#
#                      destination
# 1              Mont Saint Michel
# 2                        St Malo
# 3                         Bayeux
# 4                       Le Havre
# 5                          Rouen
# 6                          Paris
# 7                         Amiens
# 8                          Lille
# 9                     Strasbourg
# 10  Chateau du Haut Koenigsbourg
# 11                        Colmar
# 12                     Eguisheim
# 13                      Besancon
# 14                         Dijon
# 15                        Annecy
# 16                      Grenoble
# 17                          Lyon
# 18              Gorges du Verdon
# 19            Bormes les Mimosas
# 20                        Cassis
# 21                     Marseille
# 22               Aix en Provence
# 23                       Avignon
# 24                          Uzes
# 25                         Nimes
# 26                 Aigues Mortes
# 27      Saintes Maries de la mer
# 28                     Collioure
# 29                   Carcassonne
# 30                        Ariege
# 31                      Toulouse
# 32                     Montauban
# 33                      Biarritz
# 34                       Bayonne
# 35                   La Rochelle

# %%
clean_gps = gps.loc[:,['destination','lat','lon']]
clean_gps
# Out:
#                      destination                 lat                 lon
# 1              Mont Saint Michel          48.6359541  -1.511459954959514
# 2                        St Malo           48.649518          -2.0260409
# 3                         Bayeux          49.2764624          -0.7024738
# 4                       Le Havre          49.4938975           0.1079732
# 5                          Rouen          49.4404591           1.0939658
# 6                          Paris          48.8588897  2.3200410217200766
# 7                         Amiens          49.8941708           2.2956951
# 8                          Lille          50.6365654           3.0635282
# 9                     Strasbourg           48.584614           7.7507127
# 10  Chateau du Haut Koenigsbourg  48.249489800000006    7.34429620253195
# 11                        Colmar  48.111095000000006   7.363622702110888
# 12                     Eguisheim          48.0377622   7.317521300603902
# 13                      Besancon          47.2380222           6.0243622
# 14                         Dijon          47.3215806           5.0414701
# 15                        Annecy          45.8992348           6.1288847
# 16                      Grenoble          45.1875602           5.7357819
# 17                          Lyon          45.7578137           4.8320114
# 18              Gorges du Verdon          43.7496562           6.3285616
# 19            Bormes les Mimosas          43.1506968           6.3419285
# 20                        Cassis          43.2181778   5.553394005675274
# 21                     Marseille          43.2961743           5.3699525
# 22               Aix en Provence          43.5298424           5.4474738
# 23                       Avignon          43.9492493           4.8059012
# 24                          Uzes         44.02856055   4.420493673910444
# 25                         Nimes          43.8374249           4.3600687
# 26                 Aigues Mortes          43.5658225           4.1912837
# 27      Saintes Maries de la mer          43.4522771           4.4287172
# 28                     Collioure            42.52505           3.0831554
# 29                   Carcassonne          43.2130358           2.3491069
# 30                        Ariege          42.9455368  1.4065544156065486
# 31                      Toulouse          43.6044622           1.4442469
# 32                     Montauban          44.0175835           1.3549991
# 33                      Biarritz          43.4832523          -1.5592776
# 34                       Bayonne          43.4933379           -1.475099
# 35                   La Rochelle          46.1591126          -1.1520434

# %%
# request of a t of a APIkey on openweathermap.com
weather = r.get('https://api.openweathermap.org/data/2.5/onecall?lat=48.6359541&lon=-1.511459954959514&exclude=hourly,daily&appid=065e46c0a92a72de01782328806aa55a')

# %%
weather.text
# Out:
# '{"lat":48.636,"lon":-1.5115,"timezone":"Europe/Paris","timezone_offset":3600,"current":{"dt":1641894504,"sunrise":1641887747,"sunset":1641918696,"temp":282.08,"feels_like":279.89,"pressure":1030,"humidity":95,"dew_point":281.32,"uvi":0.21,"clouds":100,"visibility":10000,"wind_speed":3.9,"wind_deg":167,"wind_gust":5.9,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]},"minutely":[{"dt":1641894540,"precipitation":0},{"dt":1641894600,"precipitation":0},{"dt":1641894660,"precipitation":0},{"dt":1641894720,"precipitation":0},{"dt":1641894780,"precipitation":0},{"dt":1641894840,"precipitation":0},{"dt":1641894900,"precipitation":0},{"dt":1641894960,"precipitation":0},{"dt":1641895020,"precipitation":0},{"dt":1641895080,"precipitation":0},{"dt":1641895140,"precipitation":0},{"dt":1641895200,"precipitation":0},{"dt":1641895260,"precipitation":0},{"dt":1641895320,"precipitation":0},{"dt":1641895380,"precipitation":0},{"dt":1641895440,"precipitation":0},{"dt":1641895500,"precipitation":0},{"dt":1641895560,"precipitation":0},{"dt":1641895620,"precipitation":0},{"dt":1641895680,"precipitation":0},{"dt":1641895740,"precipitation":0},{"dt":1641895800,"precipitation":0},{"dt":1641895860,"precipitation":0},{"dt":1641895920,"precipitation":0},{"dt":1641895980,"precipitation":0},{"dt":1641896040,"precipitation":0},{"dt":1641896100,"precipitation":0},{"dt":1641896160,"precipitation":0},{"dt":1641896220,"precipitation":0},{"dt":1641896280,"precipitation":0},{"dt":1641896340,"precipitation":0},{"dt":1641896400,"precipitation":0},{"dt":1641896460,"precipitation":0},{"dt":1641896520,"precipitation":0},{"dt":1641896580,"precipitation":0},{"dt":1641896640,"precipitation":0},{"dt":1641896700,"precipitation":0},{"dt":1641896760,"precipitation":0},{"dt":1641896820,"precipitation":0},{"dt":1641896880,"precipitation":0},{"dt":1641896940,"precipitation":0},{"dt":1641897000,"precipitation":0},{"dt":1641897060,"precipitation":0},{"dt":1641897120,"precipitation":0},{"dt":1641897180,"precipitation":0},{"dt":1641897240,"precipitation":0},{"dt":1641897300,"precipitation":0},{"dt":1641897360,"precipitation":0},{"dt":1641897420,"precipitation":0},{"dt":1641897480,"precipitation":0},{"dt":1641897540,"precipitation":0},{"dt":1641897600,"precipitation":0},{"dt":1641897660,"precipitation":0},{"dt":1641897720,"precipitation":0},{"dt":1641897780,"precipitation":0},{"dt":1641897840,"precipitation":0},{"dt":1641897900,"precipitation":0},{"dt":1641897960,"precipitation":0},{"dt":1641898020,"precipitation":0},{"dt":1641898080,"precipitation":0},{"dt":1641898140,"precipitation":0}]}'

# %%
weather = weather.json()
weather
# Out:
# {'lat': 48.636,
#  'lon': -1.5115,
#  'timezone': 'Europe/Paris',
#  'timezone_offset': 3600,
#  'current': {'dt': 1641894504,
#   'sunrise': 1641887747,
#   'sunset': 1641918696,
#   'temp': 282.08,
#   'feels_like': 279.89,
#   'pressure': 1030,
#   'humidity': 95,
#   'dew_point': 281.32,
#   'uvi': 0.21,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 3.9,
#   'wind_deg': 167,
#   'wind_gust': 5.9,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}]},
#  'minutely': [{'dt': 1641894540, 'precipitation': 0},
#   {'dt': 1641894600, 'precipitation': 0},
#   {'dt': 1641894660, 'precipitation': 0},
#   {'dt': 1641894720, 'precipitation': 0},
#   {'dt': 1641894780, 'precipitation': 0},
#   {'dt': 1641894840, 'precipitation': 0},
#   {'dt': 1641894900, 'precipitation': 0},
#   {'dt': 1641894960, 'precipitation': 0},
#   {'dt': 1641895020, 'precipitation': 0},
#   {'dt': 1641895080, 'precipitation': 0},
#   {'dt': 1641895140, 'precipitation': 0},
#   {'dt': 1641895200, 'precipitation': 0},
#   {'dt': 1641895260, 'precipitation': 0},
#   {'dt': 1641895320, 'precipitation': 0},
#   {'dt': 1641895380, 'precipitation': 0},
#   {'dt': 1641895440, 'precipitation': 0},
#   {'dt': 1641895500, 'precipitation': 0},
#   {'dt': 1641895560, 'precipitation': 0},
#   {'dt': 1641895620, 'precipitation': 0},
#   {'dt': 1641895680, 'precipitation': 0},
#   {'dt': 1641895740, 'precipitation': 0},
#   {'dt': 1641895800, 'precipitation': 0},
#   {'dt': 1641895860, 'precipitation': 0},
#   {'dt': 1641895920, 'precipitation': 0},
#   {'dt': 1641895980, 'precipitation': 0},
#   {'dt': 1641896040, 'precipitation': 0},
#   {'dt': 1641896100, 'precipitation': 0},
#   {'dt': 1641896160, 'precipitation': 0},
#   {'dt': 1641896220, 'precipitation': 0},
#   {'dt': 1641896280, 'precipitation': 0},
#   {'dt': 1641896340, 'precipitation': 0},
#   {'dt': 1641896400, 'precipitation': 0},
#   {'dt': 1641896460, 'precipitation': 0},
#   {'dt': 1641896520, 'precipitation': 0},
#   {'dt': 1641896580, 'precipitation': 0},
#   {'dt': 1641896640, 'precipitation': 0},
#   {'dt': 1641896700, 'precipitation': 0},
#   {'dt': 1641896760, 'precipitation': 0},
#   {'dt': 1641896820, 'precipitation': 0},
#   {'dt': 1641896880, 'precipitation': 0},
#   {'dt': 1641896940, 'precipitation': 0},
#   {'dt': 1641897000, 'precipitation': 0},
#   {'dt': 1641897060, 'precipitation': 0},
#   {'dt': 1641897120, 'precipitation': 0},
#   {'dt': 1641897180, 'precipitation': 0},
#   {'dt': 1641897240, 'precipitation': 0},
#   {'dt': 1641897300, 'precipitation': 0},
#   {'dt': 1641897360, 'precipitation': 0},
#   {'dt': 1641897420, 'precipitation': 0},
#   {'dt': 1641897480, 'precipitation': 0},
#   {'dt': 1641897540, 'precipitation': 0},
#   {'dt': 1641897600, 'precipitation': 0},
#   {'dt': 1641897660, 'precipitation': 0},
#   {'dt': 1641897720, 'precipitation': 0},
#   {'dt': 1641897780, 'precipitation': 0},
#   {'dt': 1641897840, 'precipitation': 0},
#   {'dt': 1641897900, 'precipitation': 0},
#   {'dt': 1641897960, 'precipitation': 0},
#   {'dt': 1641898020, 'precipitation': 0},
#   {'dt': 1641898080, 'precipitation': 0},
#   {'dt': 1641898140, 'precipitation': 0}]}

# %%
#to convert the dictionary i to a dataframe with columns
weather = (pd.DataFrame([weather]))
weather
# Out:
#       lat     lon      timezone  timezone_offset  \
# 0  48.636 -1.5115  Europe/Paris             3600
#
#                                              current  \
# 0  {'dt': 1641894504, 'sunrise': 1641887747, 'sun...
#
#                                             minutely
# 0  [{'dt': 1641894540, 'precipitation': 0}, {'dt'...

# %%
# To retrieve the weather for each destination ?
for i,j in clean_gps:
    weather2 = r.get('https://api.openweathermap.org/data/2.5/onecall?lat={}&lon={}&exclude=hourly,daily&appid=065e46c0a92a72de01782328806aa55a')
    weather = weather.append(weather2.json(), ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-37a972d32c26> in <module>
#       1 # To retrieve the weather for each destination ?
# ----> 2 for i,j in clean_gps:
#       3     weather2 = r.get('https://api.openweathermap.org/data/2.5/onecall?lat={i}&lon={j}&exclude=hourly,daily&appid=065e46c0a92a72de01782328806aa55a')
#       4     weather = weather.append(weather2.json(), ignore_index=True)
#
# ValueError: too many values to unpack (expected 2)

# %%
weather
# Out:
#       lat     lon      timezone  timezone_offset  \
# 0  48.636 -1.5115  Europe/Paris           3600.0
# 1     NaN     NaN           NaN              NaN
# 2     NaN     NaN           NaN              NaN
# 3     NaN     NaN           NaN              NaN
#
#                                              current  \
# 0  {'dt': 1641894504, 'sunrise': 1641887747, 'sun...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#                                             minutely  cod         message
# 0  [{'dt': 1641894540, 'precipitation': 0}, {'dt'...  NaN             NaN
# 1                                                NaN  400  wrong latitude
# 2                                                NaN  400  wrong latitude
# 3                                                NaN  400  wrong latitude

# %%
#Nettoyer le tableau pour avoir la destination avec les critères météo souhaité
#Save all the results in a .csv file

# %%
#Scrap booking.com

# %%
#hotel name,
#Url to its booking.com page,
#Its coordinates: latitude and longitude
#Score given by the website users
#Text description of the hotel

# %%
#https://www.booking.com/searchresults.fr.html?label=gen173nr-1DCAEoggI46AdIM1gEaE2IAQGYAQ24AQfIAQ3YAQPoAQH4AQOIAgGoAgO4Aqep9Y4GwAIB0gIkZjU4YzRiZjEtNDIwNC00Yjg3LTg1NWUtNDBkNDVhMGZjNmRj2AIE4AIB&sid=836997d7e7a0eb5d392ae733c38b84b1&sb=1&sb_lp=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.fr.html%3Flabel%3Dgen173nr-1DCAEoggI46AdIM1gEaE2IAQGYAQ24AQfIAQ3YAQPoAQH4AQOIAgGoAgO4Aqep9Y4GwAIB0gIkZjU4YzRiZjEtNDIwNC00Yjg3LTg1NWUtNDBkNDVhMGZjNmRj2AIE4AIB%3Bsid%3D836997d7e7a0eb5d392ae733c38b84b1%3Bsb_price_type%3Dtotal%26%3B&ss=france&is_ski_area=0&checkin_year=&checkin_month=&checkout_year=&checkout_month=&group_adults=2&group_children=2&age=6&age=6&no_rooms=1&b_h4u_keep_filters=&from_sf=1&ss_raw=france&search_pageview_id=f96c46195c990104

# %%
import html.parser

# %%
#retrieving for the first destination
respbook = r.get("https://www.booking.com/hotel/fr/le-relais-du-roy.fr.html?aid=304142;label=gen173nr-1DCAEoggI46AdIM1gEaE2IAQGYAQ24AQfIAQ3YAQPoAQH4AQOIAgGoAgO4Aqep9Y4GwAIB0gIkZjU4YzRiZjEtNDIwNC00Yjg3LTg1NWUtNDBkNDVhMGZjNmRj2AIE4AIB;sid=836997d7e7a0eb5d392ae733c38b84b1;age=6;age=6;dest_id=900039327;dest_type=city;dist=0;group_adults=2;group_children=2;hapos=12;hpos=12;no_rooms=1;req_adults=2;req_age=6;req_age=6;req_children=2;room1=A%2CA%2C6%2C6;sb_price_type=total;sr_order=popularity;srepoch=1641896112;srpvid=f2f44817e34d0296;type=total;ucfs=1&#hotelTmpl")
respbook
# Out:
# <Response [200]>

# %%
respbook.text
# Out:
# '<!DOCTYPE html>\n<!--\nYou know you could be getting paid to poke around in our code?\nWe\'re hiring designers and developers to work in Amsterdam:\nhttps://careers.booking.com/\n-->\n<!-- wdot-802 -->\n<script type="text/javascript" nonce="306O6s4BostbP54">\ndocument.addEventListener(\'DOMContentLoaded\', function () {\n//c360 javascript tracker first iteration\n//sends a track request to c360 http tracker\n//in order to use it:\n//1. inline the c360Tracker.js in the page you need to use it\n//2. in your js file:\n//\n// var c360Tracker = B.require(\'c360Tracker\');\n// var event = {\n// action_name:"accommodation_checkout_confirmation_viewed",\n// action_version :"0.2.0",\n// content : { "transaction_id" : 123434},\n// user : { "BKNG_user_id": 123434}\n// };\n// c360Tracker.track(event);\nB.define(\'c360Tracker\', function () {\nvar enrichedContext = {};\nvar configuration = {\nvalidateInput: false\n};\nvar track = function (event) {\nif (event == null) {\nreturn "event object is null or empty";\n} else {\n//if (enrichedContext.userID != null) {\n// event.user = {BKNG_user_id: enrichedContext.userID};\n//}\nvar validationResult = new ValidationResult(true);\nif (configuration.validateInput) {\nvalidationResult = validateInput(event);\n}\nif (!validationResult.success) {\nreturn validationResult.message;\n}\nsend(event);\n}\n};\nfunction send(data) {\ndata.context = enrichedContext;\ndata.tracker = {\ntracker_name: "C360JSTracker",\ntracker_type: "Client",\ntracker_version: "0.1.0"\n};\nreturn $.ajax({\nurl: \'/c360/v1/track\',\ntype: \'POST\',\ndata: JSON.stringify(data),\n});\n}\nenrich();\nvar scheme =\n{\n"type": "object",\n"properties": {\n"action_name": {\n"type": "string",\n"description": "action name (ex. element viewed)",\n},\n"action_version": {\n"type": "string",\n"description": "action version"\n},\n"content": {\n"type": "object",\n"description": "content defined by the registered producer scheme"\n}\n}\n};\nfunction ValidationResult(success, message) {\nthis.success = success;\nthis.message = message;\n}\nfunction validateInput(event) {\nvar result = validateObject(event, scheme);\nreturn result;\n}\nfunction validateObject(obj, scheme) {\nif (scheme.properties != null) {\nvar propsArray = Object.getOwnPropertyNames(scheme.properties);\nfor (var i = 0; i < propsArray.length; i++) {\nvar propertyName = propsArray[i];\nif (obj[propertyName] == null) {\nreturn new ValidationResult(false, "property " + propertyName + " is not defined");\n}\nif (scheme.properties[propertyName].type == "object") {\nvar validationResult = validateObject(obj[propertyName], scheme.properties[propertyName]);\nif (validationResult.success === false) {\nreturn validationResult;\n}\n}\n}\n}\nreturn new ValidationResult(true);\n}\nfunction enrich() {\nenrichedContext = {\npage: {\npage_referrer: document.referrer,\npage_url: window.location.href,\npage_title: document.title\n},\nlocal: {\ncurrency: B.env.b_selected_currency\n},\n};\n//if (B.env.b_user_genius_status != null && B.env.b_user_genius_status.b_user_id != null)\n// enrichedContext.userID = B.env.b_user_genius_status.b_user_id;\n}\nreturn {\ntrack: track\n};\n});\n})\n</script>\n<script type="text/javascript" nonce="306O6s4BostbP54" src="https://cdn.cookielaw.org/consent/3ea94870-d4b1-483a-b1d2-faf1d982bb31/OtAutoBlock.js"></script>\n<script type="text/javascript" nonce="306O6s4BostbP54">\n(function () {\ndocument.addEventListener(\'cookie_banner_closed\', function(e) {\nif (window.PCM && window.B && window.B.et) {\nwindow.B.et.goal((window.PCM.Marketing || window.PCM.Analytical) ? \'cookie_consent_accepted_policy_banner\' : \'cookie_consent_declined_policy_banner\');\n}\n});\ndocument.addEventListener(\'click\', function(e) {\nif (e.target && e.target.classList.contains(\'ot-preference-center-footer\')) {\ne.preventDefault();\nOptanon && Optanon.ToggleInfoDisplay();\n}\n});\n})();\n</script>\n<script type="text/javascript" nonce="306O6s4BostbP54">\nwindow.PCM = {\nisCountryNeedCooki ...

# %%
soup = BeautifulSoup(respbook.text,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--
# You know you could be getting paid to poke around in our code?
# We're hiring designers and developers to work in Amsterdam:
# https://careers.booking.com/
# -->
# <!-- wdot-802 -->
# <script nonce="306O6s4BostbP54" type="text/javascript">
#  document.addEventListener('DOMContentLoaded', function () {
# //c360 javascript tracker first iteration
# //sends a track request to c360 http tracker
# //in order to use it:
# //1. inline the c360Tracker.js in the page you need to use it
# //2. in your js file:
# //
# // var c360Tracker = B.require('c360Tracker');
# // var event = {
# // action_name:"accommodation_checkout_confirmation_viewed",
# // action_version :"0.2.0",
# // content : { "transaction_id" : 123434},
# // user : { "BKNG_user_id": 123434}
# // };
# // c360Tracker.track(event);
# B.define('c360Tracker', function () {
# var enrichedContext = {};
# var configuration = {
# validateInput: false
# };
# var track = function (event) {
# if (event == null) {
# return "event object is null or empty";
# } else {
# //if (enrichedContext.userID != null) {
# // event.user = {BKNG_user_id: enrichedContext.userID};
# //}
# var validationResult = new ValidationResult(true);
# if (configuration.validateInput) {
# validationResult = validateInput(event);
# }
# if (!validationResult.success) {
# return validationResult.message;
# }
# send(event);
# }
# };
# function send(data) {
# data.context = enrichedContext;
# data.tracker = {
# tracker_name: "C360JSTracker",
# tracker_type: "Client",
# tracker_version: "0.1.0"
# };
# return $.ajax({
# url: '/c360/v1/track',
# type: 'POST',
# data: JSON.stringify(data),
# });
# }
# enrich();
# var scheme =
# {
# "type": "object",
# "properties": {
# "action_name": {
# "type": "string",
# "description": "action name (ex. element viewed)",
# },
# "action_version": {
# "type": "string",
# "description": "action version"
# },
# "content": {
# "type": "object",
# "description": "content defined by the registered producer scheme"
# }
# }
# };
# function ValidationResult(success, message) {
# this.success = success;
# this.message = message;
# }
# function validateInput(event) {
# var result = validateObject(event, scheme);
# return result;
# }
# function validateObject(obj, scheme) {
# if (scheme.properties != null) {
# var propsArray = Object.getOwnPropertyNames(scheme.properties);
# for (var i = 0; i < propsArray.length; i++) {
# var propertyName = propsArray[i];
# if (obj[propertyName] == null) {
# return new ValidationResult(false, "property " + propertyName + " is not defined");
# }
# if (scheme.properties[propertyName].type == "object") {
# var validationResult = validateObject(obj[propertyName], scheme.properties[propertyName]);
# if (validationResult.success === false) {
# return validationResult;
# }
# }
# }
# }
# return new ValidationResult(true);
# }
# function enrich() {
# enrichedContext = {
# page: {
# page_referrer: document.referrer,
# page_url: window.location.href,
# page_title: document.title
# },
# local: {
# currency: B.env.b_selected_currency
# },
# };
# //if (B.env.b_user_genius_status != null && B.env.b_user_genius_status.b_user_id != null)
# // enrichedContext.userID = B.env.b_user_genius_status.b_user_id;
# }
# return {
# track: track
# };
# });
# })
# </script>
# <script nonce="306O6s4BostbP54" src="https://cdn.cookielaw.org/consent/3ea94870-d4b1-483a-b1d2-faf1d982bb31/OtAutoBlock.js" type="text/javascript">
# </script>
# <script nonce="306O6s4BostbP54" type="text/javascript">
#  (function () {
# document.addEventListener('cookie_banner_closed', function(e) {
# if (window.PCM && window.B && window.B.et) {
# window.B.et.goal((window.PCM.Marketing || window.PCM.Analytical) ? 'cookie_consent_accepted_policy_banner' : 'cookie_consent_declined_policy_banner');
# }
# });
# document.addEventListener('click', function(e) {
# if (e.target && e.target.classList.contains('ot-preference-center-footer')) {
# e.preventDefault();
# Optanon && Optanon.ToggleInfoDisplay();
# }
# });
# })();
# </script>
# <script nonce="306O6s4BostbP54" type="text/javascript">
#  window.PCM = {
# isCountryNeedCookieBanner: 1,
# loadStartedAt: 1641906517
# }
# </script>
# <script data-domain-script="3ea94870-d4b1-483a-b1d2-faf1d982bb31" nonce="306O6s4BostbP54" src="https://cf.bstatic.com/libs/privacy-consent/releases/2.1.28/customer/cookie-banner.min.js" type="text/javascript">
# </script>
# <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://shelves.booking.com/" rel="preconnect"/>
# <html class="noJS b_bot b_bot supports_fontface supports_hyphens" lang="fr" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# booking_com: http://ogp.me/ns/fb/booking_com#" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head profile="http://a9.com/-/spec/opensearch/1.1/">
#   <meta content="origin" name="referrer"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type">
#    <script nonce="306O6s4BostbP54">
#     function b_cors_check(supported) { var value = supported ? 1 : 0; if (!/(^|;)\s*cors_js=/.test(document.cookie)) { var d = new Date(); d.setTime(d.getTime() + 60 * 60 * 24 * 365 * 1000); var cookieDomain = '.booking.com' || '.booking.com'; document.cookie = 'cors_js=' + value +'; domain=' + cookieDomain + '; path=/; expires=' + d.toGMTString(); } if (!value) { location.reload(); } }
#    </script>
#    <script nonce="306O6s4BostbP54">
#     (function(d) { d.addEventListener('error', function(e) { if (e.target && e.target.classList.contains('crossorigin-check-js')) { b_cors_check(false); } }, true); })(document);
#    </script>
#    <script async="" class="crossorigin-check-js" crossorigin="" nonce="306O6s4BostbP54" src="https://cf.bstatic.com/static/js/crossorigin_check_cloudfront_sd/2454015045ef79168d452ff4e7f30bdadff0aa81.js">
#    </script>
#    <script nonce="306O6s4BostbP54">
#     ;(function() {
# window.b_early_errors = window.b_early_errors || [];
# window.onerror = function() {
# window.b_early_errors.push(arguments);
# };
# }());
#    </script>
#    <script nonce="306O6s4BostbP54">
#     window.csp_action_sample = 'hotel';
#    </script>
#    <link data-main-css="1" href="https://cf.bstatic.com/static/css/main_cloudfront_sd.iq_ltr/9bc65c8d47f52c32071220c51a1f2a0d19c51cf4.css" id="main-css-preload" rel="stylesheet">
#     <script nonce="306O6s4BostbP54">
#      document.querySelector('#main-css-preload').addEventListener('load', function() {
# window.mainCssWasLoaded = 1;
# })
#     </script>
#     <link href="https://cf.bstatic.com/static/css/main_exps_cloudfront_sd.iq_ltr/c6a591b32e0e5cc9d1377f37a39ad5dca04fdeac.css" rel="stylesheet">
#      <link href="https://cf.bstatic.com/static/css/gprof_icons_cloudfront_sd.iq_ltr/b665599aa59fb0853d3b4eb1dbe5710452f928c7.css" rel="stylesheet">
#       <link href="https://cf.bstatic.com/static/css/hotel_base_cloudfront_sd.iq_ltr/06f96a2c20f05cd81e477d230ba6b4ebd958a8e7.css" media="screen" rel="stylesheet" type="text/css"/>
#       <link href="https://cf.bstatic.com/static/css/hotel_experiments_cloudfront_sd.iq_ltr/aa11639d32959b5b900cbd350685c6964aa56496.css" media="screen" rel="stylesheet" type="text/css"/>
#       <link href="https://cf.bstatic.com/static/css/hotel_experiments_rtrw_cloudfront_sd.iq_ltr/228a38bbac4c448a28f9dc60eeee64891bc8d8fe.css" media="screen" rel="stylesheet" type="text/css"/>
#       <link data-defer-prefetch="" href="https://cf.bstatic.com/static/css/searchresults_cloudfront_sd.iq_ltr/0cf269e808b822c16d0408ae184d5e656b1f120a.css" rel="_prefetch"/>
#       <link data-defer-prefetch="" href="https://cf.bstatic.com/static/css/book_cloudfront_sd.iq_ltr/c05d858f8dce695e3324a1fcbd4d77c023ad55bb.css" rel="_prefetch"/>
#       <link href="https://cf.bstatic.com/static/css/incentives_cloudfront_sd.iq_ltr/c2efa98c9abbf19eef15f6003bc3a02aaa0578c2.css" media="screen" rel="stylesheet" type="text/css">
#        <link href="https://cf.bstatic.com/static/css/mlt_cloudfront_sd.iq_ltr/5993142fd8e90ad7f4cd7f00ffaa44345c5fdf46.css" rel="stylesheet">
#         <style>
#          #basiclayout, .basiclayout { margin: 0; } #special_actions { margin: 3px 15px 3px 0; } .ticker_space { margin-top: 3px !important; } #logo_no_globe_new_logo { top: 14px; } .b_msie_6 #top, .b_msie_6 body.header_reshuffle #top {height:61px !important;} .b_msie_6 #special_actions { margin: 3px 15px 3px 0; overflow:visible; } body.header_reshuffle #top { min-height: 50px !important; height: auto !important; } .nobg { background: #fff url("https://cf.bstatic.com/static/img/nobg_all_blue_iq/b700d9e3067c1186a3364012df4fe1c48ae6da44.png") repeat-x; background-position: 0 -50px; }
#         </style>
#         <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/core-deps-inlinedet_cloudfront_sd/4e2203ea8e576ee9aaab4ddd52b59054ec915695.js" nonce="306O6s4BostbP54" rel="preload"/>
#         <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/jquery_cloudfront_sd/b7d9d30c56875df3553b561b0a06e5edf66aa9fe.js" nonce="306O6s4BostbP54" rel="preload"/>
#         <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/main_cloudfront_sd/7254324f0665fb8e6be13b444a2dc061c26fca71.js" nonce="306O6s4BostbP54" rel="preload"/>
#         <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/searchbox_cloudfront_sd/5143af228c82149776d4123be88561d75c6cbeae.js" nonce="306O6s4BostbP54" rel="preload"/>
#         <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/hotel_cloudfront_sd/b9f6f78e76461edd5e46c830f4b98a4ab4e5a23b.js" nonce="306O6s4BostbP54" rel="preload"/>
#         <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/hotel_experiments_rtrw_cloudfront_sd/5f4141edf10154096f2847c56180d45b1387af68.js" nonce="306O6s4BostbP54" rel="preload"/>
#         <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/error_catcher_bec_cloudfront_sd/282f83b6049fe9bacd964cb6ea8a6d5447528b14.js" nonce="306O6s4BostbP54" rel="preload"/>
#         <script nonce="306O6s4BostbP54">
#          if( window.performance && performance.measure && 'b-stylesheets') { performance.measure('b-stylesheets'); }
#         </script>
#         <title>
#          Le Relais Du Roy, Le Mont-Saint-Michel – Tarifs 2022
#         </title>
#         <meta content="Le Relais Du Roy est un hôtel 3 étoiles situé au bord du Couesnon, à seulement 1,5 km du Mont Saint-Michel et à 50 mètres de la navette gratuite." name="description"/>
#         <meta content="Le Relais Du Roy, Le Mont-Saint-Michel, France, R:Basse-Normandie, Hôtel, Hôtels" name="keywords"/>
#         <meta content="index,follow" name="robots"/>
#         <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.fr.html" rel="canonical">
#          <link href="android-app://com.booking/booking/hotel/53560?affiliate_id=375119" rel="alternate">
#           <meta content="UmFuZG9tSVbHxVKb_FY22rGt8o46pG49loqhxpd8booYs3frQWWxz7ZxImOu6GT5_qgxgNZkE7HXPFPNpuJDIHeV0ZlfzwOVA26Yp4HiqsBFVN9cgCfW2nujghMjHln4FVX9P3ENkPfdQhkATIkRHx6AmwlCuuffAtLs2tkIZ0ofopiAzi0stMS-tXFOj32J0zOS3o35dPSfyEaxfQJ3_MzL_u86X6MJFJQTgtMB6Awk1CR-nnYt5jDl6Yd1czlLPoNkkgGPlojSUXii73aDitw79tKLJAKGebHMVyPTDl4Qj1bKoLBkP7x3LffShwlz_rOkR9sqPf41G862N7Kqpw" name="booking-verification"/>
#           <meta content="367003839" name="twitter:app:id:iphone"/>
#           <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
#           <meta content="367003839" name="twitter:app:id:ipad"/>
#           <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
#           <meta content="com.booking" name="twitter:app:id:googleplay"/>
#           <meta content="367003839" property="al:ios:app_store_id"/>
#           <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>
#           <meta content="Booking.com Hotel Reservation" property="al:android:app_name"/>
#           <meta content="com.booking" property="al:android:package"/>
#           <meta content="Le Relais Du Roy, Le Mont-Saint-Michel, France" name="twitter:title">
#            <meta content="Le Relais Du Roy est un hôtel 3 étoiles situé au bord du Couesnon, à seulement 1,5 km du Mont Saint-Michel et à 50 mètres de la navette gratuite." name="twitter:description">
#             <meta content="https://cf.bstatic.com/xdata/images/hotel/max1024x768/122643267.jpg?k=c0186f70828e9eeb2306c01f82d769dd840f8919781b18a51cf01e0a369535f7&amp;o=&amp;hp=1" name="twitter:image">
#              <meta content="https://www.booking.com/hotel/fr/le-relais-du-roy.html?aid=375119" name="twitter:app:url:iphone">
#               <meta content="https://www.booking.com/hotel/fr/le-relais-du-roy.html?aid=375119" name="twitter:app:url:ipad"/>
#               <meta content="https://www.booking.com/hotel/fr/le-relais-du-roy.html?aid=375119" name="twitter:app:url:googleplay"/>
#               <meta content="https://www.booking.com/hotel/fr/le-relais-du-roy.html?aid=375119" property="al:ios:url"/>
#               <meta content="https://www.booking.com/hotel/fr/le-relais-du-roy.html?aid=375119" property="al:android:url"/>
#               <meta content="ff7f0b90ebb93e5bf7c7cafe77640ec1" name="p:domain_verify"/>
#               <meta content="fr" http-equiv="content-language"/>
#               <meta content="text/javascript" http-equiv="content-script-type"/>
#               <meta content="text/css" http-equiv="content-style-type"/>
#               <meta content="_top" http-equiv="window-target"/>
#               <meta content="131840030178250, 1425349334428496, 117615518393985, 1565844503706287, 517612321758712, 1668799180037291, 265097377176252, 1643712662515912, 303492549842824, 1638321783047271, 809709019119342, 959185470826086, 217466488652137, 641365839348517, 203741606405114" property="fb:pages"/>
#               <meta content="48970bbca45d28c2" property="wb:webmaster">
#                <meta content="website" property="og:type"/>
#                <meta content="summary_large_image" name="twitter:card"/>
#                <meta content="@bookingcom" name="twitter:site"/>
#                <meta content="@bookingcom" name="twitter:creator"/>
#                <meta content="★★★ Le Relais Du Roy, Le Mont-Saint-Michel, France" property="og:title">
#                 <meta content="Le Relais Du Roy est un hôtel 3 étoiles situé au bord du Couesnon, à seulement 1,5 km du Mont Saint-Michel et à 50 mètres de la navette gratuite." property="og:description">
#                  <meta content="https://cf.bstatic.com/xdata/images/hotel/max1024x768/122643267.jpg?k=c0186f70828e9eeb2306c01f82d769dd840f8919781b18a51cf01e0a369535f7&amp;o=&amp;hp=1" property="og:image">
#                   <meta content="1024" property="og:image:width"/>
#                   <meta content="682" property="og:image:height"/>
#                   <meta content="" property="booking_com:location:latitude"/>
#                   <meta content="" property="booking_com:location:longitude"/>
#                   <meta content="fr_FR" property="og:locale"/>
#                   <meta content="https://www.booking.com/hotel/fr/le-relais-du-roy.fr.html" property="og:url"/>
#                   <meta content="Booking.com" property="og:site_name"/>
#                   <meta content="145362478954725" property="fb:app_id"/>
#                   <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.en-gb.html" hreflang="en-gb" rel="alternate" title="English (UK)" type="text/html">
#                    <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.html" hreflang="en-us" rel="alternate" title="English (US)" type="text/html">
#                     <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.de.html" hreflang="de" rel="alternate" title="Deutsch" type="text/html">
#                      <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.nl.html" hreflang="nl" rel="alternate" title="Nederlands" type="text/html">
#                       <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.fr.html" hreflang="fr" rel="alternate" title="Français" type="text/html">
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.es.html" hreflang="es" rel="alternate" title="Español" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.es-ar.html" hreflang="es-ar" rel="alternate" title="Español (AR)" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.es-mx.html" hreflang="es-mx" rel="alternate" title="Español (MX)" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.ca.html" hreflang="ca" rel="alternate" title="Català" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.it.html" hreflang="it" rel="alternate" title="Italiano" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.pt-pt.html" hreflang="pt-pt" rel="alternate" title="Português (PT)" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.pt-br.html" hreflang="pt-br" rel="alternate" title="Português (BR)" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.no.html" hreflang="no" rel="alternate" title="Norsk" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.fi.html" hreflang="fi" rel="alternate" title="Suomi" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.sv.html" hreflang="sv" rel="alternate" title="Svenska" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.da.html" hreflang="da" rel="alternate" title="Dansk" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.cs.html" hreflang="cs" rel="alternate" title="Čeština" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.hu.html" hreflang="hu" rel="alternate" title="Magyar" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.ro.html" hreflang="ro" rel="alternate" title="Română" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.ja.html" hreflang="ja" rel="alternate" title="日本語" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.zh-cn.html" hreflang="zh-cn" rel="alternate" title="简体中文" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.zh-tw.html" hreflang="zh-tw" rel="alternate" title="繁體中文" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.pl.html" hreflang="pl" rel="alternate" title="Polski" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.el.html" hreflang="el" rel="alternate" title="Ελληνικά" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.ru.html" hreflang="ru" rel="alternate" title="Русский" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.tr.html" hreflang="tr" rel="alternate" title="Türkçe" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.bg.html" hreflang="bg" rel="alternate" title="Български" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.ar.html" hreflang="ar" rel="alternate" title="العربية" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.ko.html" hreflang="ko" rel="alternate" title="한국어" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.he.html" hreflang="he" rel="alternate" title="עברית" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.lv.html" hreflang="lv" rel="alternate" title="Latviski" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.uk.html" hreflang="uk" rel="alternate" title="Українська" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.id.html" hreflang="id" rel="alternate" title="Bahasa Indonesia" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.ms.html" hreflang="ms" rel="alternate" title="Bahasa Malaysia" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.th.html" hreflang="th" rel="alternate" title="ภาษาไทย" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.et.html" hreflang="et" rel="alternate" title="Eesti" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.hr.html" hreflang="hr" rel="alternate" title="Hrvatski" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.lt.html" hreflang="lt" rel="alternate" title="Lietuvių" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.sk.html" hreflang="sk" rel="alternate" title="Slovenčina" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.sr.html" hreflang="sr" rel="alternate" title="Srpski" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.sl.html" hreflang="sl" rel="alternate" title="Slovenščina" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.vi.html" hreflang="vi" rel="alternate" title="Tiếng Việt" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.tl.html" hreflang="tl" rel="alternate" title="Filipino" type="text/html"/>
#                        <link href="https://www.booking.com/hotel/fr/le-relais-du-roy.is.html" hreflang="is" rel="alternate" title="Íslenska" type="text/html"/>
#                        <link href="https://cf.bstatic.com/static/img/b25logo/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon"/>
#                        <link href="https://cf.bstatic.com/static/img/apple-touch-icon/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon"/>
#                        <link href="/faq.fr.html?sid=4e36fc5fe367dd1589deffaeb7044986;" rel="help"/>
#                        <link href="https://cf.bstatic.com/static/opensearch/fr/ab4c8e0e132d315ad6fb6ddf052295ee78c91070.xml" rel="search" title="Booking.com réservations d'hôtels en ligne" type="application/opensearchdescription+xml"/>
#                        <link href="https://plus.google.com/105443419075154950489" rel="publisher"/>
#                        <script nonce="306O6s4BostbP54" type="application/ld+json">
#                         {
#    "name" : "Le Relais Du Roy",
#    "description" : "Le Relais Du Roy est un hôtel 3 étoiles situé au bord du Couesnon, à seulement 1,5 km du Mont Saint-Michel et à 50 mètres de la navette gratuite.",
#    "url" : "https://www.booking.com/hotel/fr/le-relais-du-roy.fr.html",
#    "@type" : "Hotel",
#    "image" : "https://cf.bstatic.com/xdata/images/hotel/max500/122643267.jpg?k=c0186f70828e9eeb2306c01f82d769dd840f8919781b18a51cf01e0a369535f7&o=&hp=1",
#    "priceRange" : null,
#    "address" : {
#       "streetAddress" : "La Caserne, 50170 Le Mont-Saint-Michel, France",
#       "addressRegion" : "Basse-Normandie",
#       "@type" : "PostalAddress",
#       "addressCountry" : "France",
#       "postalCode" : "50170",
#       "addressLocality" : "La Caserne"
#    },
#    "@context" : "http://schema.org",
#    "aggregateRating" : {
#       "@type" : "AggregateRating",
#       "reviewCount" : 1310,
#       "ratingValue" : 8.1,
#       "bestRating" : 10
#    },
#    "hasMap" : "https://maps.googleapis.com/maps/api/staticmap?size=1600x1200&center=48.6162627,-1.5109058&sensor=false&zoom=15&markers=color:blue%7c48.6162627,-1.5109058&client=gme-booking&channel=booking-frontend&signature=ZhanQhfTyGWO29rvwT3ZVQ_zVTg="
# }
#                        </script>
#                        <script nonce="306O6s4BostbP54">
#                         /*
# */
# (function avoidingXSSviaLocationHash() {
# var location = window.location,
# hash = location.hash,
# xss = /[<>'"]/;
# if (
# xss.test( decodeURIComponent( hash ) ) ||
# xss.test( hash )
# ) {
# location.hash = '';
# }
# })();
# document.documentElement.className = document.documentElement.className.replace('noJS', '') + ' hasJS';
# var b_experiments = {}, WIDTH, B = window.booking = {
# _onfly: [], // "on the fly" functions, will be executed as soon as external js files were loaded
# devTools: {
# trackedExperiments: []
# },
# user: {
# },
# env : {
# isRetina : window.devicePixelRatio > 1,
# "b_gtt": 'dLYAeZFVJfNTBBScUYcbfdVfVDSOCPLDRMYNET',
# "b_action" : 'hotel',
# "b_secure_domain" : 'https://secure.booking.com',
# "b_site_type" : 'www',
# "b_site_type_id": '1',
# "b_query_params_with_lang_no_ext": '?sid=4e36fc5fe367dd1589deffaeb7044986',
# "b_query_params_with_lang_no_ext_enforce_lang_aid_currency": '?sid=4e36fc5fe367dd1589deffaeb7044986;lang=fr;aid=304142;selected_currency=EUR',
# "b_calendar2" : '1',
# /*
# */
# "b_partner_channel_id": '3',
# "b_bookings_owned": '1',
# "b_google_maps_key_params" : 'true&indexing=true',
# "b_lang" : 'fr',
# "b_has_valid_dates": 0,
# "b_countrycode" : 'fr',
# "b_guest_country" : 'fr',
# "b_locale" : 'fr-fr',
# "b_lang_for_url" : 'fr',
# "b_this_urchin" : '/hotel/fr/le-relais-du-roy.fr.html?',
# "b_flag_to_suggest" : 'fr',
# "b_companyname" : 'Booking.com',
# "b_partner_vertical" : 'channel_direct',
# b_date_format: {"date_without_year":"{day_of_month} {month_name}","short_date":"{day_of_month} {short_month_name} {full_year}","day_short_month_year_time":"{day_of_month} {short_month_name} {full_year}, {time}","numeric_day_month_year_time_before":"avant le {day_name_0}/{month_name_0}/{full_year} à {time}","day_short_month_year_until":"jusqu'au {day_name} {short_month_name} {full_year}","date_with_weekday_to":"{weekday_to} {day_of_month} {month_name_to} {full_year}","month_with_year":"{month_name_with_year_only} {full_year}","day_month":"{day_name} {month_name}","in_month_with_year":"en {month_name_in} {full_year}","day_month_until":"jusqu'au {day_name} {month_name}","day_short_month_time":"{day_of_month} {short_month_name}, {time}","date_with_weekday_time_from":"{weekday} {begin_marker}{day_of_month} {month_name}{end_marker} {full_year} à partir de {time}","numeric_date_range_both_years":"{day_of_month}/{month}/{full_year} - {day_of_month_until}/{month_until}/{full_year_until}","short_date_without_year":"{day_of_month} {short_month_name}","day_short_month_year_between":"{day_of_month} {short_month_name} {full_year} - {day_of_month_until} {short_month_name_until} {full_year_until}","numeric_day_month_year_on":"le {day_name_0}/{month_name_0}/{full_year}","short_month_only":"{short_month_name}","day_month_year_between":"entre le {day_name} {month_name} {full_year} et le {day_name_until} {month_name_until} {full_year_until}","date_with_short_weekday_without_year":"{short_weekday} {day_of_month} {month_name}","day_short_month_year":"{day_name} {short_month_name} {full_year}","numeric_day_month_year":"{day_name_0}/{month_name_0}/{full_year}","day_short_month":"{day_name} {short_month_name}","day_short_month_from":"du {day_name} {short_month_name}","date_with_weekday_time_until":"{weekday} {begin_marker}{day_of_month} {month_name}{end_marker} {full_year} jusqu'à {time}","numeric_date_range":"{day_of_month}/{month} - {day_of_month_until}/{month_until}","short_date_with_weekday":"{short_weekday} {day_of_month} {short_month_name} {full_year}","date_with_year":"{day_of_month} {month_name} {full_year}","day_short_month_year_on":"le {day_name} {short_month_name} {full_year}","from_month_with_year":"depuis {month_name_from} {full_year}","day_short_month_year_time_between":"{day_of_month} {short_month_name} {full_year}, {time} - {time_until}","day_short_month_until":"jusqu'au {day_name} {short_month_name}","long_date_range_both_years":"{day_of_month} {month_name} {full_year} - {day_of_month_until} {month_name_until} {full_year_until}","day_short_month_year_other":"{day_name_other} {short_month_name} {full_year}","date_with_weekday_with_markers":"{weekday} {begin_marker}{day_of_month} {month_name}{end_marker} {full_year}","date_range_with_short_weekday_short_month":"{short_weekday} {day_of_month} {short_month_name} - {short_weekday_until} {day_of_month_until} {short_month_name_until}","date_with_weekday_time_at":"date_with_weekday_time_at","date_with_weekday":"{weekday} {day_of_month} {month_name} {full_year}","day_month_from":"du {day_name} {month_name}","ux_day_month":"","day_month_year_on":"le {day_name} {month_name} {full_year}","day_month_year_from":"du {day_name} {month_name} {full_year}","day_short_month_on":"le {day_name} {short_month_name}","short_month_with_year":"{short_month_name} {full_year}","date_with_short_weekday_with_year":"{short_weekday} {day_of_month} {month_name} {full_year}","ux_day_month_on":"le {day_2} {month_2}","range_from_long_date_time_until_long_date_time":"du {day_of_month} {month_name} {full_year} à {time} jusqu'au {day_of_month_until} {month_name_until} {full_year_until} à {time_until}","short_date_with_weekday_without_year":"{short_weekday} {day_of_month} {short_month_name}","date_with_weekday_from":"{weekday_from} {day_of_month} {month_name_from} {full_year}","day_short_month_time_between":"{day_of_month} {short_month_name}, {time} - {time_until}","day_month_year_other":"{day_other} {month_name} {full_year} ...
# b_month_for_formatted_date: {"1":{"in_month_lc":"en janvier","genitive_uc":"Janvier","name_with_year_only":"janvier","name_only":"janvier","name_in":"janvier","month_1":"janvier","name_other":"janvier","name_from":"janvier","name_def_article_uc":"Le mois de janvier","short_name":"janv.","name":"janvier","name_lc":"janvier","day_to":"janvier","month_2":"janvier","name_to":"janvier","short_name_uc":"janvier","name_uc":"de janvier","genitive_lc":"janvier","to_month_lc":"janvier","name_def_article_lc":"le mois de janvier","on_day_month":"01"},"10":{"on_day_month":"10","to_month_lc":"octobre","name_def_article_lc":"le mois d'octobre","name_lc":"octobre","month_2":"octobre","name_to":"octobre","short_name_uc":"octobre","name":"octobre","short_name":"oct.","genitive_lc":"octobre","name_uc":"d'octobre","name_def_article_uc":"Le mois d'octobre","name_other":"octobre","name_from":"octobre","month_1":"octobre","genitive_uc":"Octobre","in_month_lc":"en octobre","name_with_year_only":"octobre","name_only":"octobre","name_in":"octobre"},"11":{"name_def_article_lc":"le mois de novembre","to_month_lc":"novembre","on_day_month":"11","name":"novembre","short_name":"nov.","name_to":"novembre","short_name_uc":"novembre","name_lc":"novembre","month_2":"novembre","name_uc":"de novembre","genitive_lc":"novembre","month_1":"novembre","name_def_article_uc":"Le mois de novembre","name_other":"novembre","name_from":"novembre","in_month_lc":"en novembre","genitive_uc":"Novembre","name_in":"novembre","name_only":"novembre","name_with_year_only":"novembre"},"12":{"month_1":"décembre","name_from":"décembre","name_other":"décembre","name_def_article_uc":"Le mois de décembre","in_month_lc":"en décembre","genitive_uc":"Décembre","name_only":"décembre","name_with_year_only":"décembre","name_in":"décembre","to_month_lc":"décembre","name_def_article_lc":"le mois de décembre","on_day_month":"12","name":"décembre","short_name":"déc.","name_lc":"décembre","month_2":"décembre","short_name_uc":"décembre","name_to":"décembre","name_uc":"de décembre","genitive_lc":"décembre"},"2":{"month_1":"février","name_other":"février","name_def_article_uc":"Le mois de février","name_from":"février","name_only":"février","name_with_year_only":"février","name_in":"février","genitive_uc":"Février","in_month_lc":"en février","to_month_lc":"février","name_def_article_lc":"le mois de février","on_day_month":"02","name_uc":"de février","genitive_lc":"février","name":"février","short_name":"févr.","day_to":"février","name_lc":"février","month_2":"février","name_to":"février","short_name_uc":"février"},"3":{"to_month_lc":"mars","name_def_article_lc":"le mois de mars","on_day_month":"03","name":"mars","short_name":"mars","name_lc":"mars","day_to":"mars","month_2":"mars","short_name_uc":"mars","name_to":"mars","name_uc":"de mars","genitive_lc":"mars","month_1":"mars","name_from":"mars","name_other":"mars","name_def_article_uc":"Le mois de mars","in_month_lc":"en mars","genitive_uc":"Mars","name_with_year_only":"mars","name_only":"mars","name_in":"mars"},"4":{"name_other":"avril","name_from":"avril","name_def_article_uc":"Le mois d'avril","month_1":"avril","name_only":"avril","name_with_year_only":"avril","name_in":"avril","genitive_uc":"Avril","in_month_lc":"en avril","on_day_month":"04","to_month_lc":"avril","name_def_article_lc":"le mois d'avril","genitive_lc":"avril","name_uc":"d'avril","name_lc":"avril","month_2":"avril","name_to":"avril","short_name_uc":"avril","name":"avril","short_name":"avr."},"5":{"in_month_lc":"en mai","genitive_uc":"Mai","name_in":"mai","name_with_year_only":"mai","name_only":"mai","name_other":"mai","name_from":"mai","name_def_article_uc":"Le mois de mai","month_1":"mai","name_to":"mai","short_name_uc":"mai","name_lc":"mai","month_2":"mai","short_name":"mai","name":"mai","genitive_lc":"mai","name_uc":"de mai","on_day_month":"05","name_def_article_lc":"le mois de mai","to_month_lc":"mai"},"6":{"name_def_article_lc":"le mois de juin","to_month_lc":"juin","on_day_mon ...
# b_weekday_formatted_date: {"1":{"name_other_uc":"lundi","short":"lun","name_from":"lundi","name_other":"lundi","name_on":"lundi","name_uc":"Lundi","short_uc":"Lun.","name":"lundi","name_to":"lundi","shortest":"lu","name_lc":"lundi"},"2":{"name_from":"mardi","name_other":"mardi","name_other_uc":"mardi","short":"mar","shortest":"ma","name_to":"mardi","name_lc":"mardi","short_uc":"Mar.","name":"mardi","name_uc":"Mardi","name_on":"mardi"},"3":{"name_on":"mercredi","name_uc":"Mercredi","short_uc":"Mer.","name":"mercredi","name_lc":"mercredi","shortest":"me","name_to":"mercredi","short":"mer","name_other_uc":"mercredi","name_from":"mercredi","name_other":"mercredi"},"4":{"short":"jeu","name_other_uc":"jeudi","name_other":"jeudi","name_from":"jeudi","name":"jeudi","short_uc":"Jeu.","name_lc":"jeudi","name_to":"jeudi","shortest":"je","name_uc":"Jeudi","name_on":"jeudi"},"5":{"name_on":"vendredi","name_uc":"Vendredi","shortest":"ve","name_to":"vendredi","name_lc":"vendredi","name":"vendredi","short_uc":"Ven.","name_from":"vendredi","name_other":"vendredi","name_other_uc":"vendredi","short":"ven"},"6":{"name_other":"samedi","name_from":"samedi","short":"sam","name_other_uc":"samedi","name_on":"samedi","name_lc":"samedi","name_to":"samedi","shortest":"sa","short_uc":"Sam.","name":"samedi","name_uc":"Samedi"},"7":{"name_on":"dimanche","name_uc":"Dimanche","short_uc":"Dim.","name":"dimanche","name_lc":"dimanche","shortest":"di","name_to":"dimanche","short":"dim","name_other_uc":"dimanche","name_from":"dimanche","name_other":"dimanche"},"8":{"name_other_uc":"name_other_uc","short":"short","name_other":"name_other","name_from":"name_from","name_on":"name_on","name_uc":"name_uc","short_uc":"short_uc","name":"Tous les jours","name_to":"name_to","shortest":"shortest","name_lc":"every day"}},
# b_time_format: {"AM_symbol":{"name":"AM"},"PM_symbol":{"name":"PM"},"time":{"name":"{hour_24h_no0}h{minutes}"}},
# "b_protocol": 'https',
# b01: 1,
# auth_level : "0",
# b_user_auth_level_is_none : 1,
# b_check_ot_consent : 1,
# bui: {
# color: {
# bui_color_grayscale_dark: "#333333",
# bui_color_grayscale: "#6B6B6B",
# bui_color_grayscale_light: "#BDBDBD",
# bui_color_grayscale_lighter: "#E6E6E6",
# bui_color_grayscale_lightest: "#F5F5F5",
# bui_color_primary_dark: "#00224F",
# bui_color_primary: "#003580",
# bui_color_primary_light: "#BAD4F7",
# bui_color_primary_lighter: "#EBF3FF",
# bui_color_primary_lightest: "#FAFCFF",
# bui_color_complement_dark: "#CD8900",
# bui_color_complement: "#FEBB02",
# bui_color_complement_light: "#FFE08A",
# bui_color_complement_lighter: "#FDF4D8",
# bui_color_complement_lightest: "#FEFBF0",
# bui_color_callout_dark: "#BC5B01",
# bui_color_callout: "#FF8000",
# bui_color_callout_light: "#FFC489",
# bui_color_callout_lighter: "#FFF0E0",
# bui_color_callout_lightest: "#FFF8F0",
# bui_color_destructive_dark: "#A30000",
# bui_color_destructive: "#CC0000",
# bui_color_destructive_light: "#FCB4B4",
# bui_color_destructive_lighter: "#FFEBEB",
# bui_color_destructive_lightest: "#FFF0F0",
# bui_color_constructive_dark: "#006607",
# bui_color_constructive: "#008009",
# bui_color_constructive_light: "#97E59C",
# bui_color_constructive_lighter: "#E7FDE9",
# bui_color_constructive_lightest: "#F1FEF2",
# bui_color_action: "#0071C2",
# bui_color_white: "#FFFFFF",
# bui_color_black: "#000000"
# }
# },
# bb: {
# ibb: "",
# uibb: "",
# ibbta: "",
# itp: "0",
# iuibb: "",
# bme: "",
# euibb: "",
# tp: "2"
# },
# b_growls_close_fast: 1,
# fe_enable_login_with_phone_number: 1,
# asyncLoader: {
# async_assistant_entrypoint_css: 'https://cf.bstatic.com/static/css/assistant_entrypoint_cloudfront_sd.iq_ltr/828028cb1433e9442a919c1a1ee87b1546789753.css',
# async_assistant_entrypoint_js: 'https://cf.bstatic.com/static/js/assistant_entrypoint_cloudfront_sd/eedfd8b3b2afb306a8e93fc59a4ca677762d4844.js',
# async_atlas_places_js: 'https://cf.bstatic.com/static/js/atlas_places_async_cloudfront_sd/9a9bcd998016ecc6409aa42c8605f7850a767a34.js',
# async_atlas_v2_cn_js: 'https://cf.bstatic.com/static/js/async_atlas_v2_cn_cloudfront_sd/998f9d0f02083e7e5ed04b9c515512ed9cd30072.js',
# async_atlas_v2_non_cn_js: 'https://cf.bstatic.com/static/js/async_atlas_v2_non_cn_cloudfront_sd/154353d95ba925f2449b32eaf36992ae229a5d3d.js',
# image_gallery_js: 'https://cf.bstatic.com/static/js/ski_lp_overview_panel_cloudfront_sd/9d8e7cfd33a37ffb15285d98f6970024f06cf36d.js',
# image_gallery_css: 'https://cf.bstatic.com/static/css/ski_lp_overview_panel_cloudfront_sd.iq_ltr/e905a114a7e2a2092dfa73ce9ac18c326a2d9a25.css',
# async_lists_js: 'https://cf.bstatic.com/static/js/async_lists_cloudfront_sd/ab3b0b4b65b0e7072d51d7b080a0e2ddff3e7c57.js',
# async_atlas_css: 'https://cf.bstatic.com/static/css/async_atlas_hp_cloudfront_sd.iq_ltr/80e70db764df035fac1fd7b9d0b04c6e64ed2385.css',
# async_hp_atlas_map_js: 'https://cf.bstatic.com/static/js/async_hp_atlas_map_cloudfront_sd/21510407d3aeec802c38f959d15d96a51a59b2b8.js',
# async_wpm_overlay_css: 'https://cf.bstatic.com/static/css/async_wpm_overlay_assets_cloudfront_sd.iq_ltr/abb304bf3600a5cf5f7406a27f042cf1ce2429b1.css',
# async_wpm_overlay_js: 'https://cf.bstatic.com/static/js/async_wpm_overlay_assets_cloudfront_sd/c6cb9b63eea61102d4e96fe72b7c8008652fe925.js',
# async_slider_view_js: 'https://cf.bstatic.com/mobile/js/async_slider_view_cloudfront_sd/b99d37dd0f12a56f66e827b1f34dbf846a345b1f.js',
# async_slider_view_css: 'https://cf.bstatic.com/mobile/css/async_slider_view_cloudfront_sd.iq_ltr/3d514cbc5d5049f6ec0363aa35ed0de242954933.css',
# async_beach_team_pilot_js: 'https://cf.bstatic.com/mobile/js/async_beach_team_pilot_cloudfront_sd/29c0a8f3466daf3086e96b8a4ff02579f69f6b89.js',
# async_beach_team_pilot_css: 'https://cf.bstatic.com/mobile/css/async_beach_team_pilot_cloudfront_sd.iq_ltr/0186644857d59495f88f972513228732d5a7204f.css',
# async_room_lightbox_js: 'https://cf.bstatic.com/static/js/async_room_lightbox_cloudfront_sd/4da128681dec6592a8e6f2b10eeceb16a82cf6ba.js',
# async_questions_answers_search: 'https://cf.bstatic.com/static/js/async_questions_answers_search_cloudfront_sd/db745857d7dbf8d9c3c97d382e3f0909a9ad485b.js',
# empty: ''
# },
# b_gallery_slide_onview: 1,
# fe_enable_fps_goal_with_value: 1,
# b_email_validation_regex : /^([\w-\.\+]+@([\w-]+\.)+[\w-]{2,14})?$/,
# b_domain_end : '.booking.com',
# b_original_url : 'https:&#47;&#47;www.booking.com&#47;hotel&#47;fr&#47;le-relais-du-roy.fr.html',
# b_this_url : '/hotel/fr/le-relais-du-roy.fr.html?sid=4e36fc5fe367dd1589deffaeb7044986',
# b_this_url_without_lang : '/hotel/fr/le-relais-du-roy.html?sid=4e36fc5fe367dd1589deffaeb7044986',
# b_referrer : '',
# b_acc_type : '204',
# b_req_login: '',
# jst : {'loading': true},
# keep_day_month: true,
# b_timestamp : 1641906516,
# scripts_tracking : {
# atlas:{loaded:false,run:false},
# atlas_cst:{loaded:false,run:false},
# bhc:{loaded:false,run:false},
# calendar2:{loaded:false,run:false},
# hotel:{loaded:false,run:false},
# jquery:{loaded:false,run:false},
# main:{loaded:false,run:false}
# },
# enable_scripts_tracking : 1,
# b_ufi : '900039327',
# "setvar_affiliate_is_bookings2" : 1,
# transl_close_x : 'Fermer',
# transl_checkin_title: 'Du ',
# transl_checkout_title: 'Au ',
# browser_lang: '',
# b_hijri_calendar_available: false,
# b_aid: '304142',
# b_label: 'gen000nr-10CAsoTUIQbGUtcmVsYWlzLWR1LXJveUgNWARoTYgBAZgBM7gBBcgBHtgBA-gBAfgBAYgCAagCAbgC04L2jgbAAgHSAiRlMGE3ZjU2Zi1hMThlLTRlZGEtYmE1Zi00ZWFlYWY0YTdmZjDYAgHgAgE',
# b_sid: '4e36fc5fe367dd1589deffaeb7044986',
# ip_country: 'fr',
# country_currency: 'EUR',
# b_selected_currency: 'EUR',
# b_selected_currency_is_hotel_currency: "",
# b_selected_language: 'fr',
# b_selected_language_country_flag: 'fr',
# pageview_id: '52ad5c696d2001d7',
# aid: '304142',
# b_csrf_token: 'k7ndYQAAAAA=JOeD7fOSnLitjNyXtV_18fWOqc2Q25dPUb8qfyB42KTjJy2xpexdKYGLJ1UQr8PO2cXHBvQtx5VQeW9UL_Of-IrMEGCp-vIanXr-78lW9vP2npfzvRZLoZx95EBhCtvYhThLq9SsQC-5HtOqYsluf44jdnXM4bZZnuYze2GnUdgYzZtzDt-G_7hUYWmJrBVqNGQgIkV_eHlG0_ZS',
# b_show_user_accounts_features: 1,
# b_browser: 'bot',
# et_debug_level: '0',
# icons: '/static/img',
# b_static_images: 'https://cf.bstatic.com/images/',
# b_currency_url: '/general.fr.html?sid=4e36fc5fe367dd1589deffaeb7044986;tmpl=currency_foldout;cur_currency=EUR;cc1=fr',
# b_languages_url: '/general.fr.html?sid=4e36fc5fe367dd1589deffaeb7044986;tmpl=language_foldout',
# b_weekdays: [
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('1'),
# "name": 'lundi',
# "short": 'lun.',
# "shorter": 'lun.',
# "shortest": 'lu'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('2'),
# "name": 'mardi',
# "short": 'mar.',
# "shorter": 'mar.',
# "shortest": 'ma'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('3'),
# "name": 'mercredi',
# "short": 'mer.',
# "shorter": 'mer.',
# "shortest": 'me'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('4'),
# "name": 'jeudi',
# "short": 'jeu.',
# "shorter": 'jeu.',
# "shortest": 'je'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('5'),
# "name": 'vendredi',
# "short": 'ven.',
# "shorter": 'ven.',
# "shortest": 've'},
# {"b_is_weekend": parseInt( '1' ),
# "b_number": parseInt('6'),
# "name": 'samedi',
# "short": 'sam.',
# "shorter": 'sam.',
# "shortest": 'sa'},
# {"b_is_weekend": parseInt( '1' ),
# "b_number": parseInt('7'),
# "name": 'dimanche',
# "short": 'dim.',
# "shorter": 'dim.',
# "shortest": 'di'},
# {}],
# b_group: [],
# b_group_rooms_wanted: 1,
# b_simple_weekdays: ['lu','ma','me','je','ve','sa','di'],
# b_simple_weekdays_for_js: ['lun.','mar.','mer.','jeu.','ven.','sam.','dim.'],
# b_long_weekdays: ['lundi','mardi','mercredi','jeudi','vendredi','samedi','dimanche'],
# b_short_months: ['janvier','février','mars','avril','mai','juin','juillet','août','septembre','octobre','novembre','décembre'],
# b_short_months_abbr: ['janv.','févr.','mars','avr.','mai','juin','juill.','août','sept.','oct.','nov.','déc.'],
# b_year_months: {
# '2022-1': {'name': 'janvier 2022' },
# '2022-2': {'name': 'février 2022' },
# '2022-3': {'name': 'mars 2022' },
# '2022-4': {'name': 'avril 2022' },
# '2022-5': {'name': 'mai 2022' },
# '2022-6': {'name': 'juin 2022' },
# '2022-7': {'name': 'juillet 2022' },
# '2022-8': {'name': 'août 2022' },
# '2022-9': {'name': 'septembre 2022' },
# '2022-10': {'name': 'octobre 2022' },
# '2022-11': {'name': 'novembre 2022' },
# '2022-12': {'name': 'décembre 2022' },
# '2023-1': {'name': 'janvier 2023' },
# '2023-2': {'name': 'février 2023' },
# '2023-3': {'name': 'mars 2023' },
# '2023-4': {'name': 'avril 2023' }
# },
# b_user_is_new: 1,
# b_is_landing : 1,
# b_user_auth_level_is_none: 1,
# b_is_fb_safe: 1,
# b_is_app: 1,
# first_page_of_results: true,
# b_partner_id: '1',
# b_is_destination_finder_supported: 0,
# b_is_dsf: 0,
# b_pr_param: '',
# /*
# */
# hotelAction: {
# showReviews: parseInt("1310", 10),
# minReviews: parseInt("3", 10),
# hotelName: "le-relais-du-roy",
# pageLang: "fr",
# hotelCountry: "fr"
# ,has_business_reviews: true
# },
# feature_profile_split_sb_checkbox: 1,
# inandaround_more: "Plus",
# b_signup_iframe_url: 'https://secure.booking.com' + '/login.html?tmpl=profile/signup_after_subscribe' + '&lang=fr' ,
# b_exclude_lang_firstname: 0,
# view_prices_enter_dates: 'Veuillez saisir vos dates pour voir les tarifs et les disponibilités.',
# autocomplete_categories: {
# city: 'Villes',
# region: 'Régions',
# airport: 'Aéroports',
# hotel: 'Hôtels',
# landmark: 'Sites d\'intérêt',
# country: 'Pays',
# district: 'Quartiers / Arrondissements',
# theme: 'Thèmes'
# },
# autocomplete_skip_suggestions: 'Rechercher plus d\'options',
# autocomplete_counter_label: 'Établissements à proximité',
# autocomplete : {
# property_nearby: '1 établissement à proximité',
# properties_nearby: ' établissements à proximité',
# hotel: 'établissement',
# hotels: 'établissements',
# hotels_nearby: 'Établissements à proximité'
# },
# lists: {
# collection: [
# {
# id: "0",
# name: "Mon prochain voyage",
# hotels_count: "0"
# }
# ]
# },
# touch_os: false,
# calendar_days_allowed_number: 354,
# b_search_max_months: 16,
# b_run_ge_new_newsletter_login: 1,
# b_password_strength_msg: ['Pas assez de caractères','Faible','Correct','Bon','Fort','Très fort'],
# b_passwd_min_length_error: 'Votre mot de passe doit comporter au moins 8 caractères',
# b_password_must_be_numeric: 'Le code confidentiel de votre réservation doit contenir 4 chiffres. Veuillez réessayer.',
# b_bkng_nr_must_be_numeric: 'Votre numéro de réservation doit contenir 9 chiffres. Veuillez réessayer.',
# b_blank_numeric_pin: 'Veuillez saisir votre code confidentiel.',
# b_blank_bkng_nr: 'Veuillez saisir votre numéro de réservation.',
# password_cant_be_username: 'Votre adresse e-mail et votre mot de passe ne peuvent être identiques',
# b_show_passwd: 'Voir le mot de passe',
# b_passwd_tooltip: 'Insérez des majuscules, des caractères spéciaux et des chiffres pour augmenter le niveau de sécurité de votre mot de passe',
# account_error_add_password: 'Veuillez entrer votre mot de passe',
# password_needs_8: 'Votre mot de passe doit comporter au moins 8 caractères',
# error_sign_up_password_email_combo_01: 'Votre adresse e-mail ou votre mot de passe est incorrect, veuillez recommencer.',
# social_plugins_footer: 1,
# b_lazy_load_print_css: 1,
# print_css_href: 'https://cf.bstatic.com/static/css/print/0cc4ce4b7108d42a9f293fc9b654f749d84ba4eb.css',
# 'component/dropdown-onload-shower/header_signin_prompt' : {
# b_action: "hotel"
# ,fe_can_see_genius_signed_out_communication: 1
# },
# b_hostname_signup: "www.booking.com",
# b_nonsecure_hostname: "https://www.booking.com",
# b_nonsecure_hostname_signup: "https://www.booking.com",
# b_fd_searchresults_url_signup: "",
# translation_customer_service_which_booking_no_specific: 'Pas de réservation spécifique',
# stored_past_and_upcoming_bookings: [
# ],
# global_translation_tags: {"rlm":"\u200f","one_dot_leader":"\u2024","lrm":"\u200e","zwsp":"\u200b","nbsp":"&nbsp;","line_break":"\u003cbr\u003e"},
# b_hotel_id: '53560',
# b_hotel_name: 'Le Relais Du Roy',
# b_hotel_image_url_square60: 'https://cf.bstatic.com/xdata/images/hotel/square60/122643267.jpg?k=c0186f70828e9eeb2306c01f82d769dd840f8919781b18a51cf01e0a369535f7&o=&hp=1',
# hotelPhotos: [
# {
# id: '122643267',
# thumb_url: 'https://cf.bstatic.com/xdata/images/hotel/max200/122643267.jpg?k=c0186f70828e9eeb2306c01f82d769dd840f8919781b18a51cf01e0a369535f7&o=&hp=1',
# large_url: 'https://cf.bstatic.com/xdata/images/hotel/max1024x768/122643267.jpg?k=c0186f70828e9eeb2306c01f82d769dd840f8919781b18a51cf01e0a369535f7&o=&hp=1'
# ,highres_url: 'https://cf.bstatic.com/xdata/images/hotel/max1280x900/122643267.jpg?k=c0186f70828e9eeb2306c01f82d769dd840f8919781b18a51cf01e0a369535f7&o=&hp=1'
# ,associated_rooms: [
# '5356002'
# ,'5356008'
# ,'5356009'
# ]
# ,orientation: 'landscape'
# ,created : '2017-12-15 19:30:13'
# ,grid: {
# photo_width: 7087,
# photo_height: 4724,
# gridTrack:[
# {
# track: "customGoal:aXBNTfZHQSVTMIHMDVYeCIObTae:1",
# on:'click'
# }
# ]
# }
# }
# ,
# {
# id: '122644237',
# ...
#    </path>
#    <path d="M116.4 103.7c-.9-2-2-3.8-1.4-6 1.3-4.3 2.8-8.6 4-13a34.5 34.5 0 0 0 1-9.7c0-4.8-2.7-9.3-4-14-.6-2.1-1.7-4-.6-6.3s2.3-4.4 3.6-6.7c2-3.6.3-8.1-2-10-2.5-2-5.8-2-9-1-4 1.3-7 2-11 3a25.3 25.3 0 0 1-7 1c-2.5-.2-4-1.6-6-3a8.2 8.2 0 0 0-8-1c-2.8 1.1-5.5 2.3-8.3 3.3a9.8 9.8 0 0 1-7.4 0c-2.9-1-5.5-2.1-8.3-3.3a8.2 8.2 0 0 0-8 1c-2 1.4-3.5 2.8-6 3a25.3 25.3 0 0 1-7-1c-4-1-7-1.7-11-3-3.2-1-6.5-1-9 1-2.3 1.9-4 6.4-2 10l3.5 6.7c1.1 2.3 0 4.2-.5 6.3-1.3 4.6-4 9.2-4 14a34.5 34.5 0 0 0 1 9.8c1.2 4.3 2.7 8.6 4 12.9.5 2.1-.6 4-1.4 6a43.7 43.7 0 0 0-2.5 4.8C8 112 9 116 12 118a9 9 0 0 0 7.7 1.4L32 116a10.4 10.4 0 0 1 6.8-.2c2.2.7 4.3 1.8 6.5 2.6a28.6 28.6 0 0 0 4.4 1.4c2.8.6 5.2-.6 7.4-2C59 116.4 62 115 64 115s5 1.5 7 2.7c2.1 1.5 4.5 2.7 7.3 2.1a28.6 28.6 0 0 0 4.4-1.4c2.2-.8 4.3-1.9 6.5-2.6a10.4 10.4 0 0 1 6.8.2l12.3 3.5a9 9 0 0 0 7.7-1.5c3-2 4-6 2.8-9.6a43.7 43.7 0 0 0-2.4-4.7zM16.7 113a1.8 1.8 0 1 1 1.8-1.8 1.8 1.8 0 0 1-1.8 1.8zm0-66.5a1.8 1.8 0 1 1 1.8-1.8 1.8 1.8 0 0 1-1.8 1.8zM106 99a7 7 0 0 1-7 7H29a7 7 0 0 1-7-7V57a7 7 0 0 1 7-7h70a7 7 0 0 1 7 7zm5.3 14a1.8 1.8 0 1 1 1.7-1.8 1.8 1.8 0 0 1-1.7 1.8zm0-66.5a1.8 1.8 0 1 1 1.7-1.7 1.8 1.8 0 0 1-1.7 1.7z">
#    </path>
#    <path d="M70.8 20.9L90 40l2-2-19.6-19.6a9.7 9.7 0 0 1-1.6 2.5z">
#    </path>
#    <circle cx="85.2" cy="66.8" r="10.8">
#    </circle>
#    <polygon points="99 102 81 84 73.8 91.2 55.8 73.2 27 102 99 102">
#    </polygon>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -iconset-attractions" focusable="false" height="128" role="presentation" style="display:none;" viewbox="0 0 128 128" width="128">
#    <path d="M110 54a10 10 0 0 0-3 .5 43.7 43.7 0 0 0-5.9-14.2A10 10 0 1 0 87.6 27a43.7 43.7 0 0 0-14-5.8 10 10 0 1 0-19 0 43.7 43.7 0 0 0-14 5.8 10 10 0 1 0-13.7 13.4A43.7 43.7 0 0 0 21 54.5a10 10 0 1 0 0 19 43.7 43.7 0 0 0 5.8 14A10 10 0 1 0 40.3 101a43.8 43.8 0 0 0 10.3 4.9l-2 10.5a3 3 0 0 0 2.9 3.6h24.8a3 3 0 0 0 3-3.6L77.2 106a43.8 43.8 0 0 0 10.7-5 10 10 0 1 0 13.5-14 43.7 43.7 0 0 0 5.6-13.6 10 10 0 1 0 3-19.5zm-36.3 7.5a10 10 0 0 0-1.2-2.7l18.6-18.5a35.8 35.8 0 0 1 8.8 21.2zM69 55.3a10 10 0 0 0-2.5-1V28.1a35.8 35.8 0 0 1 21 8.7zm-7.5-1a10 10 0 0 0-2.6 1.1L40.3 37a35.8 35.8 0 0 1 21.2-8.9zM55.4 59a10 10 0 0 0-1 2.5H28a35.8 35.8 0 0 1 8.7-21zm-1 7.5a10 10 0 0 0 1 2.5L36.8 87.5a35.8 35.8 0 0 1-8.7-21zM91 87.3L72.6 69a10 10 0 0 0 1-2.5H100a35.8 35.8 0 0 1-8.1 20.4l-.7.4zm-50.8 3.8l18.5-18.5a10 10 0 0 0 2.7 1V90h-5.2a3 3 0 0 0-3 2.4l-1 5.6a36 36 0 0 1-12-7zm34.2 1.3a3 3 0 0 0-3-2.4h-5V73.7a10 10 0 0 0 2.7-1.1L87.6 91l-.1.3A36 36 0 0 1 75.6 98z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -iconset-monument" focusable="false" height="128" role="presentation" style="display:none;" viewbox="0 0 128 128" width="128">
#    <path d="M96 116a4 4 0 0 1-4 4H36a4 4 0 0 1 0-8h56a4 4 0 0 1 4 4zm-46-12h28a2 2 0 0 0 2-2.1l-3.9-77.6a2 2 0 0 0-.4-1l-10-14.5a2 2 0 0 0-3.3 0L52.3 23.2a2 2 0 0 0-.4 1.1L48 102a2 2 0 0 0 2 2.1z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -iconset-triangle_down" focusable="false" height="128" role="presentation" style="display:none;" viewbox="0 0 128 128" width="128">
#    <path d="m40 56 24 24 24-24z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -iconset-magnifying_glass" focusable="false" height="128" role="presentation" style="display:none;" viewbox="0 0 128 128" width="128">
#    <path d="M118.8 113.2l-31-31A4 4 0 0 0 85 81a44 44 0 1 0-4 4 4 4 0 0 0 1.2 2.8l31 31a4 4 0 0 0 5.6-5.7zM52 88a36 36 0 1 1 36-36 36 36 0 0 1-36 36z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -streamline-magnifying_glass" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24">
#    <path d="M17.464 6.56a8.313 8.313 0 1 1-15.302 6.504A8.313 8.313 0 0 1 17.464 6.56zm1.38-.586C16.724.986 10.963-1.339 5.974.781.988 2.9-1.337 8.662.783 13.65c2.12 4.987 7.881 7.312 12.87 5.192 4.987-2.12 7.312-7.881 5.192-12.87zM15.691 16.75l7.029 7.03a.75.75 0 0 0 1.06-1.06l-7.029-7.03a.75.75 0 0 0-1.06 1.06z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -streamline-house" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24">
#    <path d="M3 18v3.75A2.25 2.25 0 0 0 5.25 24h4.5a.75.75 0 0 0 .75-.75v-6a.75.75 0 0 1 .75-.75h1.5a.75.75 0 0 1 .75.75v6c0 .414.336.75.75.75h4.5A2.25 2.25 0 0 0 21 21.75V18a.75.75 0 0 0-1.5 0v3.75a.75.75 0 0 1-.75.75h-4.5l.75.75v-6A2.25 2.25 0 0 0 12.75 15h-1.5A2.25 2.25 0 0 0 9 17.25v6l.75-.75h-4.5a.75.75 0 0 1-.75-.75V18A.75.75 0 0 0 3 18zm-1.72-.97L11.47 6.841a.75.75 0 0 1 1.06 0l10.19 10.19a.75.75 0 1 0 1.06-1.061L13.591 5.78a2.25 2.25 0 0 0-3.182 0L.219 15.97a.75.75 0 1 0 1.061 1.06zm15.97-7.28v-1.5L16.5 9h3.75l-.75-.75v5.25a.75.75 0 0 0 1.5 0V8.25a.75.75 0 0 0-.75-.75H16.5a.75.75 0 0 0-.75.75v1.5a.75.75 0 0 0 1.5 0zM16.522.3l-.407.543a1.793 1.793 0 0 0 .279 2.461c.12.102.14.28.045.406l-.411.548a.75.75 0 1 0 1.2.9l.407-.543a1.793 1.793 0 0 0-.279-2.461.295.295 0 0 1-.045-.406l.411-.548a.75.75 0 1 0-1.2-.9zm3.75 0l-.407.543a1.793 1.793 0 0 0 .279 2.461c.12.102.14.28.045.406l-.411.548a.75.75 0 1 0 1.2.9l.407-.543a1.793 1.793 0 0 0-.279-2.461.295.295 0 0 1-.045-.406l.411-.548a.75.75 0 1 0-1.2-.9z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -streamline-attractions" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24">
#    <path d="M13.5 3a1.5 1.5 0 1 1-3 0 1.5 1.5 0 0 1 3 0zM15 3a3 3 0 1 0-6 0 3 3 0 0 0 6 0zm6 4.5a1.5 1.5 0 1 1-3 0 1.5 1.5 0 0 1 3 0zm1.5 0a3 3 0 1 0-6 0 3 3 0 0 0 6 0zM6 7.5a1.5 1.5 0 1 1-3 0 1.5 1.5 0 0 1 3 0zm1.5 0a3 3 0 1 0-6 0 3 3 0 0 0 6 0zM21 15a1.5 1.5 0 1 1-3 0 1.5 1.5 0 0 1 3 0zm1.5 0a3 3 0 1 0-6 0 3 3 0 0 0 6 0zm-9-3.75a1.5 1.5 0 1 1-3 0 1.5 1.5 0 0 1 3 0zm1.5 0a3 3 0 1 0-6 0 3 3 0 0 0 6 0zM6 15a1.5 1.5 0 1 1-3 0 1.5 1.5 0 0 1 3 0zm1.5 0a3 3 0 1 0-6 0 3 3 0 0 0 6 0zm10.066 1.277a7.5 7.5 0 0 1-3.077 2.05.75.75 0 0 0 .498 1.415 9 9 0 0 0 3.693-2.46.75.75 0 1 0-1.114-1.005zm1.798-6.466c.177.922.183 1.869.015 2.792a.75.75 0 1 0 1.476.268c.2-1.106.194-2.24-.019-3.344a.75.75 0 1 0-1.472.284zm-5.337-5.784a7.5 7.5 0 0 1 3.54 2.196.75.75 0 0 0 1.113-1.004 9.002 9.002 0 0 0-4.247-2.636.75.75 0 1 0-.406 1.444zM6.434 6.223a7.5 7.5 0 0 1 3.539-2.196.75.75 0 1 0-.406-1.444A9.001 9.001 0 0 0 5.32 5.219a.75.75 0 0 0 1.114 1.004zM4.636 12.69a7.602 7.602 0 0 1 0-2.878.75.75 0 1 0-1.472-.284 9.102 9.102 0 0 0 0 3.446.75.75 0 0 0 1.472-.284zm4.876 5.639a7.517 7.517 0 0 1-3.035-2.005.75.75 0 0 0-1.106 1.014 9.017 9.017 0 0 0 3.641 2.405.75.75 0 1 0 .5-1.414zM7.31 21.872A1.5 1.5 0 0 0 8.672 24h6.656a1.5 1.5 0 0 0 1.362-2.128l-3.314-8.217c-.361-.785-1.252-1.114-2.005-.767a1.5 1.5 0 0 0-.733.734l-3.343 8.283zm1.377.595l3.328-8.25-.015.033 3.313 8.217.015.033H8.672z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -streamline-pin" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24">
#    <path d="M15.25 7.5a3.75 3.75 0 1 1-7.5 0 3.75 3.75 0 0 1 7.5 0zm1.5 0a5.25 5.25 0 1 0-10.5 0 5.25 5.25 0 0 0 10.5 0zm-5.625-.75a.375.375 0 0 1-.375-.375.75.75 0 0 0 1.5 0c0-.621-.504-1.125-1.125-1.125a.75.75 0 0 0 0 1.5zm.375-.375a.375.375 0 0 1-.375.375.75.75 0 0 0 0-1.5c-.621 0-1.125.504-1.125 1.125a.75.75 0 0 0 1.5 0zM11.125 6c.207 0 .375.168.375.375a.75.75 0 0 0-1.5 0c0 .621.504 1.125 1.125 1.125a.75.75 0 0 0 0-1.5zm-.375.375c0-.207.168-.375.375-.375a.75.75 0 0 0 0 1.5c.621 0 1.125-.504 1.125-1.125a.75.75 0 0 0-1.5 0zm0 5.625v9a.75.75 0 0 0 1.5 0v-9a.75.75 0 0 0-1.5 0z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -streamline-plus" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24">
#    <path d="M20.25 11.25h-7.5v-7.5a.75.75 0 0 0-1.5 0v7.5h-7.5a.75.75 0 0 0 0 1.5h7.5v7.5a.75.75 0 0 0 1.5 0v-7.5h7.5a.75.75 0 0 0 0-1.5z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -streamline-transport_metro" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24">
#    <path d="M1.316 23.755l2.37-2.73a.75.75 0 0 0-1.132-.983l-2.37 2.73a.75.75 0 0 0 1.132.983zm22.5-.984l-2.37-2.729a.75.75 0 0 0-1.132.984l2.37 2.729a.75.75 0 0 0 1.132-.984zM21 9.013c0 5.765-4.036 12-9 12s-9-6.235-9-12c0-4.636 3.3-7.5 9-7.5s9 2.864 9 7.5zm1.5 0c0-5.516-4.016-9-10.5-9s-10.5 3.484-10.5 9c0 6.492 4.536 13.5 10.5 13.5s10.5-7.008 10.5-13.5zm-10.483 13.5a8.728 8.728 0 0 0 6.503-3.132.75.75 0 0 0 .162-.615c-.476-2.615-3.338-4.502-6.682-4.502-3.344 0-6.208 1.887-6.682 4.502a.75.75 0 0 0 .162.615 8.728 8.728 0 0 0 6.503 3.132zm0-1.5a7.228 7.228 0 0 1-5.385-2.594l.162.615c.33-1.822 2.527-3.27 5.206-3.27 2.679 0 4.875 1.448 5.206 3.27l.162-.615a7.228 7.228 0 0 1-5.385 2.594zm3.733-16.5h-7.5a3 3 0 0 0 0 6h7.5a3 3 0 1 0 0-6zm0 1.5a1.5 1.5 0 0 1 0 3h-7.5a1.5 1.5 0 1 1 0-3h7.5z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -streamline-distance" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24">
#    <path d="M22.5 4.5c0 1.127-1.484 3.863-3.312 6.622a.375.375 0 0 1 .625 0C17.993 8.38 16.5 5.627 16.5 4.5a3 3 0 1 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0c0 1.574 1.512 4.362 3.563 7.45a1.126 1.126 0 0 0 1.875 0C22.498 8.842 24 6.074 24 4.5zm-4.5.375a.375.375 0 0 1-.375-.375.75.75 0 0 0 1.5 0c0-.621-.504-1.125-1.125-1.125a.75.75 0 0 0 0 1.5zm.375-.375a.375.375 0 0 1-.375.375.75.75 0 0 0 0-1.5c-.621 0-1.125.504-1.125 1.125a.75.75 0 0 0 1.5 0zm-.375-.375c.207 0 .375.168.375.375a.75.75 0 0 0-1.5 0c0 .621.504 1.125 1.125 1.125a.75.75 0 0 0 0-1.5zm-.375.375c0-.207.168-.375.375-.375a.75.75 0 0 0 0 1.5c.621 0 1.125-.504 1.125-1.125a.75.75 0 0 0-1.5 0zM5.25 13.125a.375.375 0 0 1-.375-.375.75.75 0 0 0 1.5 0c0-.621-.504-1.125-1.125-1.125a.75.75 0 0 0 0 1.5zm.375-.375a.375.375 0 0 1-.375.375.75.75 0 0 0 0-1.5c-.621 0-1.125.504-1.125 1.125a.75.75 0 0 0 1.5 0zm-.375-.375c.207 0 .375.168.375.375a.75.75 0 0 0-1.5 0c0 .621.504 1.125 1.125 1.125a.75.75 0 0 0 0-1.5zm-.375.375c0-.207.168-.375.375-.375a.75.75 0 0 0 0 1.5c.621 0 1.125-.504 1.125-1.125a.75.75 0 0 0-1.5 0zM5.25 9A3.75 3.75 0 0 1 9 12.75c0 1.302-1.62 3.954-3.75 6.676-2.132-2.728-3.75-5.374-3.75-6.676A3.75 3.75 0 0 1 5.25 9zm0-1.5A5.25 5.25 0 0 0 0 12.75c0 1.797 1.677 4.54 4.068 7.6a1.5 1.5 0 0 0 2.364 0c2.387-3.052 4.068-5.802 4.068-7.6 0-2.9-2.35-5.25-5.25-5.25zm1.907 16.38l12.75-8.25a.75.75 0 1 0-.814-1.26l-12.75 8.25a.75.75 0 0 0 .814 1.26z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -streamline-arrow_menu" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24">
#    <path d="M12 20.09a1.24 1.24 0 0 1-.88-.36L6 14.61a.75.75 0 1 1 1.06-1.06L12 18.49l4.94-4.94A.75.75 0 0 1 18 14.61l-5.12 5.12a1.24 1.24 0 0 1-.88.36zm6-9.46a.75.75 0 0 0 0-1.06l-5.12-5.11a1.24 1.24 0 0 0-1.754-.006l-.006.006L6 9.57a.75.75 0 0 0 0 1.06.74.74 0 0 0 1.06 0L12 5.7l4.94 4.93a.73.73 0 0 0 .53.22c.2 0 .39-.078.53-.22z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -streamline-heart_outline" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24">
#    <path d="M12.541 21.325l-9.588-10a4.923 4.923 0 1 1 6.95-6.976l1.567 1.566a.75.75 0 0 0 1.06 0l1.566-1.566a4.923 4.923 0 0 1 6.963 6.962l-9.6 10.014h1.082zm-1.082 1.038a.75.75 0 0 0 1.082 0l9.59-10.003a6.418 6.418 0 0 0-.012-9.07 6.423 6.423 0 0 0-9.083-.001L11.47 4.854h1.06l-1.566-1.566a6.423 6.423 0 1 0-9.082 9.086l9.577 9.99z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -streamline-heart" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24">
#    <path d="M23.3 5.076a6.582 6.582 0 0 0-10.446-1.71L12 4.147l-.827-.753a6.522 6.522 0 0 0-5.688-1.806A6.472 6.472 0 0 0 .7 5.075a6.4 6.4 0 0 0 1.21 7.469l9.373 9.656a1 1 0 0 0 1.434 0l9.36-9.638A6.414 6.414 0 0 0 23.3 5.076z">
#    </path>
#   </svg>
#   <svg aria-hidden="true" class="bk-icon -streamline-sports_winter_free_skiing" focusable="false" height="24" role="presentation" style="display:none;" viewbox="0 0 24 24" width="24">
#    <path d="M15.62 6.45a3.14 3.14 0 1 0-3.13-3.14 3.15 3.15 0 0 0 3.13 3.14Zm0-4.77A1.64 1.64 0 1 1 14 3.31a1.64 1.64 0 0 1 1.62-1.63ZM23.26 18.64a.74.74 0 0 0-1-.31l-.33.17-3.59-6.69a2.19 2.19 0 0 0 .48-1.37 2.25 2.25 0 0 0-2.24-2.26h-1.89l-1.84-2a3.5 3.5 0 0 0-4.53-.58L3.7 8.71A3.05 3.05 0 0 0 4 14l2.82 1.47-1.14 1.21a2.33 2.33 0 0 0-.56 1.25l-3.38-1.69a.75.75 0 0 0-1 .33.76.76 0 0 0 .34 1L13 23.52a2.78 2.78 0 0 0 1.26.3 2.74 2.74 0 0 0 1.33-.34l.82-.45a.75.75 0 0 0-.72-1.32l-.82.46a1.3 1.3 0 0 1-1.2 0l-4.78-2.36.11-.12 2.6-2.89a2.81 2.81 0 0 0-.8-4.37l-2.6-1.35 1.9-1.26 1.9 2.12a2.22 2.22 0 0 0 1.66.74h2.86a2 2 0 0 0 .5-.06l3.58 6.58-.54.29a.75.75 0 0 0-.31 1 .74.74 0 0 0 .66.39.72.72 0 0 0 .35-.08l.55-.3.44.83a.77.77 0 0 0 .67.4.73.73 0 0 0 .35-.09.76.76 0 0 0 .31-1l-.45-.82.32-.17a.75.75 0 0 0 .31-1.01Zm-6.7-7.46H13.7a.77.77 0 0 1-.56-.25l-2.51-2.76a.5.5 0 0 0-.63-.08l-3.79 2.54a.61.61 0 0 0 0 1l3.88 2.09a1.31 1.31 0 0 1 .69.92 1.28 1.28 0 0 1-.31 1.11l-2.56 2.93a.71.71 0 0 1-.55.25.77.77 0 0 1-.51-.19.76.76 0 0 1 0-1.06l1.79-2a.73.73 0 0 0-.21-1.15l-3.74-1.91A1.56 1.56 0 0 1 4.54 10l4.62-3.16a2 2 0 0 1 2.58.32L14 9.68h2.54a.75.75 0 0 1 0 1.5Z">
#    </path>
#   </svg>
#   <div class="map_full_overlay__wrapper">
#    <div class="map_full_overlay__mask">
#    </div>
#    <div aria-label="Close map" class="map_full_overlay__close" role="button" tabindex="0">
#    </div>
#    <div aria-label="Map View" aria-modal="true" class="b_map_br_zoom b_map_custom_zoom map_view" id="b_map_container" role="dialog">
#     <div class="b_map_controls_container">
#     </div>
#     <div class="hp_map_elements_container">
#     </div>
#     <div id="b_map_tiles">
#      <div id="b_gmap_inner">
#      </div>
#      <div id="b_overlay">
#      </div>
#      <div id="map_detail_overlay">
#      </div>
#      <div id="b_map_legend_html">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div style="display: none;">
#    <svg aria-hidden="true" class="bk-icon -fonticon-aclose" focusable="false" height="32" role="presentation" viewbox="0 0 36 32" width="36">
#     <path d="M34 3.2L30.8 0 18 12.8 5.2 0 2 3.2 14.8 16 2 28.8 5.2 32 18 19.2 30.8 32l3.2-3.2L21.2 16 34 3.2z">
#     </path>
#    </svg>
#    <svg aria-hidden="true" class="bk-icon -fonticon-downchevron" focusable="false" height="32" role="presentation" viewbox="0 0 51 32" width="51">
#     <path d="M45.1.2L25.7 19.7 6.3.2 0 6.5l25.7 25.7L51.4 6.5z">
#     </path>
#    </svg>
#    <svg aria-hidden="true" class="bk-icon -fonticon-upchevron" focusable="false" height="32" role="presentation" viewbox="0 0 51 32" width="51">
#     <path d="M6.3 32.2l19.4-19.5 19.4 19.5 6.3-6.3L25.7.2 0 25.9z">
#     </path>
#    </svg>
#    <svg aria-hidden="true" class="bk-icon -fonticon-checkempty" focusable="false" height="32" role="presentation" viewbox="0 0 32 32" width="32">
#     <path d="M16 30c7.732 0 14-6.268 14-14S23.732 2 16 2 2 8.268 2 16s6.268 14 14 14zm0 2C7.163 32 0 24.837 0 16S7.163 0 16 0s16 7.163 16 16-7.163 16-16 16z">
#     </path>
#    </svg>
#    <svg aria-hidden="true" class="bk-icon -fonticon-checkno2" focusable="false" height="32" role="presentation" viewbox="0 0 32 32" width="32">
#     <path d="M16 30c7.732 0 14-6.268 14-14S23.732 2 16 2 2 8.268 2 16s6.268 14 14 14zm0 2C7.163 32 0 24.837 0 16S7.163 0 16 0s16 7.163 16 16-7.163 16-16 16z">
#     </path>
#     <path d="M24.587 11.039L13.825 21.583c-.054.09-.12.182-.208.271l-.504.505c-.278.278-.607.403-.733.276l-5.125-5.366c-.126-.126-.002-.454.276-.732l.504-.505c.279-.279.607-.403.733-.277l3.842 4.022L23.073 9.525a.715.715 0 0 1 1.009 0l.505.505a.715.715 0 0 1 0 1.009z">
#     </path>
#    </svg>
#   </div>
#   <span id="req_info" style="display:none;">
#    1464010,1469810,1469830,1472380,1470590,1469830|2,1469910|1,1470980,1465560,1455560,1470650,1440500,1464770,1440500|1,1469800,1470860,1440500|4,1455560|2
#   </span>
#  </body>
# </html>

# %%
hotel = soup.select('h2.fn')
hotel
# Out:
# [<h2 class="fn" id="hp_hotel_name">
#  <span class="hp__hotel-type-badge">Hôtel</span>
#  Le Relais Du Roy
#  </h2>]

# %%
# Out:
# '[<h2 class="fn" id="hp_hotel_name">\n<span class="hp__hotel-type-badge">Hôtel</span>\nLe Relais Du Roy\n</h2>]'

# %%
type(hotel)
# Out:
# bs4.element.ResultSet

# %%
Name_hotel.text.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-35539b3559c0> in <module>
# ----> 1 Name_hotel.text.split()
#
# /opt/conda/lib/python3.8/site-packages/bs4/element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
